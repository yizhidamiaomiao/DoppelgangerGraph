# %%
import networkx as nx
import scipy.sparse as sp
import numpy as np
import utils
import torch
import torch
from collections import defaultdict
import numpy as np
import time
import json

# %%
seed=114514
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.seed_all()

# %% [markdown]
# # **Read data**

# %%
loader = np.load('split.npy').item()
train_ones = loader['train_ones']
val_ones = loader['val_ones']
val_zeros = loader['val_zeros']
test_ones = loader['test_ones']
test_zeros = loader['test_zeros']
test_edges=test_ones
test_edges_false=test_zeros
print(len(train_ones))
print(np.max(train_ones))
print(np.max(test_ones))
# Out:
# 13566
# 2809
# 2796

# %%
adj_sparse = np.zeros((np.max(train_ones)+1,np.max(train_ones)+1))
for e in train_ones:
    adj_sparse[e[0],e[1]]=1
    adj_sparse[e[1],e[0]]=1
    
adj_sparse = sp.coo_matrix(adj_sparse).tocsr()

lcc = utils.largest_connected_components(adj_sparse)
adj_sparse= adj_sparse[lcc,:][:,lcc]
_N = adj_sparse.shape[0]
print('n',_N)
_Edges=[]
for x in np.column_stack(adj_sparse.nonzero()):
    if not x[0]==x[1]:
        _Edges.append((x[0],x[1]))
_num_of_edges=int(len(_Edges)/2)
print('m',_num_of_edges)

dic=defaultdict(set)
for x in _Edges:
    a1=x[0]
    a2=x[1]
    dic[a1].add(a2)
    dic[a2].add(a1)
    

adj_origin=np.zeros((_N,_N)).astype(int)
for (i,j) in _Edges:
    adj_origin[i][j]=1
    adj_origin[j][i]=1
assert(np.sum(adj_origin==adj_origin.T)==_N*_N)
assert(np.sum(adj_origin)==_num_of_edges*2)
# Out:
# Selecting 1 largest connected components
# n 2810
# m 6783

# %% [markdown]
# # **1.Get link prediction model and embedding**

# %%
embedding_dim=128

graphsagemodel=utils.GraphSAGE(_N=_N,_M=_num_of_edges,adj_origin=adj_origin,
                                         adj_dic=dic,embedding_dim=embedding_dim)

# %% [markdown]
# # *1.1 Training step*

# %%
graphsagemodel.graphsage_train(boost_times=20,add_edges=1000,training_epoch=5000,
                               boost_epoch=5000,learning_rate=0.001,save_number=0)
graphsagemodel.save_model(path='graphsage_model/graphsage.pth',embedding_path='graphsage_model/embeddings.npy')
# Out:
# 3946645
# 6783
# -13566
# Training GraphSAGE model
# Epoch:0,Loss:0.693416,estimated time:1499.39
#  acc:0.5
# Epoch:1000,Loss:0.033757,estimated time:527.80
#  acc:0.9844464101430046
# Epoch:2000,Loss:0.013573,estimated time:384.58
#  acc:0.9918177797434763
# Epoch:3000,Loss:0.029529,estimated time:243.99
#  acc:0.9917440660474717
# Epoch:4000,Loss:0.002887,estimated time:132.59
#  acc:0.9946926138876603
# 2809/2810[(1.0, 0, 39), (1.0, 0, 83), (1.0, 0, 1550), (1.0, 0, 1245), (1.0, 0, 1297), (1.0, 0, 1556), (1.0, 1, 834), (1.0, 0, 2158), (1.0, 0, 1250), (1.0, 0, 1298)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:1016, 0.07
# False Positve:12550, 0.93
# True Negative:7869984, 1.00
# False Negative:12550, 0.00
# Positive:0.00
# Negative:1.00
# Start boosting
# boost iter:0
# train_add:0
# train added: 1000
# current training set length: 14566
# current save path: graphsage_model/graphsage0_0.pth
# Epoch:0,Loss:0.378265,estimated time:665.21
#  acc:0.9395166826857064
# Epoch:1000,Loss:0.011428,estimated time:473.83
#  acc:0.990182617053412
# Epoch:2000,Loss:0.029295,estimated time:370.11
#  acc:0.9936152684333379
# Epoch:3000,Loss:0.023443,estimated time:244.03
#  acc:0.9932720032953454
# Epoch:4000,Loss:0.007954,estimated time:125.89
#  acc:0.9961554304544831
# 2809/2810[(1.0, 0, 1200), (1.0, 0, 1245), (1.0, 0, 1550), (1.0, 0, 1250), (1.0, 0, 1305), (1.0, 0, 1556), (1.0, 0, 1994), (1.0, 0, 2241), (1.0, 0, 1251), (1.0, 0, 1308)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:2398, 0.18
# False Positve:11168, 0.82
# True Negative:7871366, 1.00
# False Negative:11168, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:1
# train_add:564
# train added: 1000
# current training set length: 15566
# current save path: graphsage_model/graphsage0_1.pth
# Epoch:0,Loss:0.217253,estimated time:636.84
#  acc:0.9401901580367468
# Epoch:1000,Loss:0.052823,estimated time:501.16
#  acc:0.9809841963253244
# Epoch:2000,Loss:0.021140,estimated time:376.38
#  acc:0.9924836181421046
# Epoch:3000,Loss:0.025643,estimated time:251.14
#  acc:0.9920981626622125
# Epoch:4000,Loss:0.007756,estimated time:122.00
#  acc:0.9938327123217269
# 2809/2810[(0.99999976, 1898, 1921), (0.99999976, 1911, 2749), (0.99999976, 1907, 2015), (0.99999976, 1932, 2758), (0.99999976, 1916, 1955), (0.99999976, 1917, 2742), (0.99999976, 1920, 1956), (0.99999976, 1941, 2040), (0.99999976, 1993, 2716), (0.99999976, 1921, 1956)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:3122, 0.23
# False Positve:10444, 0.77
# True Negative:7872090, 1.00
# False Negative:10444, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:2
# train_add:895
# train added: 1000
# current training set length: 16566
# current save path: graphsage_model/graphsage0_2.pth
# Epoch:0,Loss:0.232028,estimated time:605.26
#  acc:0.9490522757455029
# Epoch:1000,Loss:0.046768,estimated time:494.17
#  acc:0.9821320777496076
# Epoch:2000,Loss:0.063681,estimated time:395.91
#  acc:0.9904623928528311
# Epoch:3000,Loss:0.019197,estimated time:250.80
#  acc:0.9914282264879875
# Epoch:4000,Loss:0.030048,estimated time:125.75
#  acc:0.9921526017143547
# 2809/2810[(0.9999993, 2238, 2674), (0.9999994, 5, 714), (0.9999993, 2298, 2742), (0.9999994, 6, 413), (0.9999994, 6, 433), (0.9999993, 2351, 2504), (0.9999994, 6, 503), (0.9999994, 138, 2391), (0.9999994, 6, 442), (0.9999994, 55, 84)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:4044, 0.30
# False Positve:9522, 0.70
# True Negative:7873012, 1.00
# False Negative:9522, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:3
# train_add:973
# train added: 1000
# current training set length: 17566
# current save path: graphsage_model/graphsage0_3.pth
# Epoch:0,Loss:0.321108,estimated time:604.35
#  acc:0.9480245929636798
# Epoch:1000,Loss:0.137932,estimated time:537.89
#  acc:0.988102015256746
# Epoch:2000,Loss:0.021349,estimated time:366.48
#  acc:0.9916315609700558
# Epoch:3000,Loss:0.041708,estimated time:247.50
#  acc:0.9866788113400888
# Epoch:4000,Loss:0.013018,estimated time:129.70
#  acc:0.9914038483433907
# 2809/2810[(0.99999774, 60, 1487), (0.99999774, 87, 337), (0.99999774, 227, 326), (0.99999774, 94, 2448), (0.99999774, 188, 2327), (0.99999774, 266, 379), (0.99999774, 298, 1702), (0.99999774, 250, 251), (0.99999774, 234, 1509), (0.99999774, 233, 347)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:4970, 0.37
# False Positve:8596, 0.63
# True Negative:7873938, 1.00
# False Negative:8596, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:4
# train_add:974
# train added: 1000
# current training set length: 18566
# current save path: graphsage_model/graphsage0_4.pth
# Epoch:0,Loss:0.186766,estimated time:716.16
#  acc:0.952439943983626
# Epoch:1000,Loss:0.021193,estimated time:507.07
#  acc:0.9890660346870623
# Epoch:2000,Loss:0.026055,estimated time:390.54
#  acc:0.9897123774641818
# Epoch:3000,Loss:0.013923,estimated time:237.11
#  acc:0.9896046536679952
# Epoch:4000,Loss:0.045886,estimated time:125.13
#  acc:0.9845416352472262
# 2809/2810[(0.99998045, 57, 64), (0.99998045, 1226, 2481), (0.99998045, 1185, 1558), (0.99998045, 1795, 2587), (0.99998045, 1303, 2096), (0.99998045, 1802, 2013), (0.99998045, 2006, 2197), (0.99998057, 249, 472), (0.99998057, 84, 162), (0.9999807, 1385, 1793)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:5110, 0.38
# False Positve:8456, 0.62
# True Negative:7874078, 1.00
# False Negative:8456, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:5
# train_add:929
# train added: 1000
# current training set length: 19566
# current save path: graphsage_model/graphsage0_5.pth
# Epoch:0,Loss:0.211656,estimated time:678.29
#  acc:0.9466421343146274
# Epoch:1000,Loss:0.022699,estimated time:506.67
#  acc:0.9868649698456506
# Epoch:2000,Loss:0.062287,estimated time:371.24
#  acc:0.9885004599816007
# Epoch:3000,Loss:0.037564,estimated time:241.74
#  acc:0.9896759685168148
# Epoch:4000,Loss:0.013321,estimated time:120.74
#  acc:0.9913625677195135
# 2809/2810[(0.9999964, 615, 1975), (0.9999964, 758, 2167), (0.9999964, 818, 2484), (0.9999964, 893, 1883), (0.9999964, 854, 2505), (0.9999964, 872, 1809), (0.9999964, 862, 2526), (0.9999964, 1043, 2331), (0.9999964, 1060, 2703), (0.9999964, 1195, 1643)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:5918, 0.44
# False Positve:7648, 0.56
# True Negative:7874886, 1.00
# False Negative:7648, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:6
# train_add:838
# train added: 1000
# current training set length: 20566
# current save path: graphsage_model/graphsage0_6.pth
# Epoch:0,Loss:0.325984,estimated time:628.48
#  acc:0.9675192064572595
# Epoch:1000,Loss:0.039734,estimated time:509.87
#  acc:0.9881843819896917
# Epoch:2000,Loss:0.011344,estimated time:384.56
#  acc:0.9863366721773802
# Epoch:3000,Loss:0.041211,estimated time:242.11
#  acc:0.9898375960322863
# Epoch:4000,Loss:0.038685,estimated time:127.26
#  acc:0.9935816395993388
# 2809/2810[(0.9997608, 1134, 1159), (0.99976116, 1053, 1059), (0.99976295, 1777, 1778), (0.9997615, 590, 1505), (0.9997621, 728, 2736), (0.9997644, 633, 834), (0.9997631, 971, 2259), (0.9997619, 247, 284), (0.9997619, 49, 64), (0.9997644, 676, 834)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:6976, 0.51
# False Positve:6590, 0.49
# True Negative:7875944, 1.00
# False Negative:6590, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:7
# train_add:972
# train added: 1000
# current training set length: 21566
# current save path: graphsage_model/graphsage0_7.pth
# Epoch:0,Loss:0.202321,estimated time:648.50
#  acc:0.9326717982008718
# Epoch:1000,Loss:0.012922,estimated time:500.03
#  acc:0.9847908745247148
# Epoch:2000,Loss:0.063469,estimated time:374.48
#  acc:0.9891959565983492
# Epoch:3000,Loss:0.155297,estimated time:261.09
#  acc:0.9884076787535936
# Epoch:4000,Loss:0.027727,estimated time:127.17
#  acc:0.9916535287025874
# 2809/2810[(0.999508, 1947, 2760), (0.9995086, 558, 1261), (0.9995084, 509, 542), (0.99950874, 636, 2102), (0.99950945, 1506, 2322), (0.9995086, 2401, 2513), (0.99951005, 1195, 2280), (0.99950874, 1482, 1774), (0.9995135, 1881, 1887), (0.999511, 205, 2796)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:7862, 0.58
# False Positve:5704, 0.42
# True Negative:7876830, 1.00
# False Negative:5704, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:8
# train_add:996
# train added: 1000
# current training set length: 22566
# current save path: graphsage_model/graphsage0_8.pth
# Epoch:0,Loss:0.165696,estimated time:614.91
#  acc:0.9559071169015333
# Epoch:1000,Loss:0.066616,estimated time:513.11
#  acc:0.9818310732961092
# Epoch:2000,Loss:0.017077,estimated time:378.69
#  acc:0.9870158645750243
# Epoch:3000,Loss:0.033559,estimated time:249.81
#  acc:0.9906939643711778
# Epoch:4000,Loss:0.048060,estimated time:127.73
#  acc:0.9878578392271559
# 2809/2810[(0.9994585, 1624, 2119), (0.99945873, 975, 2456), (0.9994605, 392, 2259), (0.99945897, 1148, 1406), (0.99946266, 710, 782), (0.9994624, 1268, 1671), (0.9994617, 525, 589), (0.9994667, 1119, 1189), (0.9994604, 1148, 2056), (0.99946314, 2270, 2339)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:8330, 0.61
# False Positve:5236, 0.39
# True Negative:7877298, 1.00
# False Negative:5236, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:9
# train_add:956
# train added: 1000
# current training set length: 23566
# current save path: graphsage_model/graphsage0_9.pth
# Epoch:0,Loss:0.129700,estimated time:696.01
#  acc:0.9521768649749639
# Epoch:1000,Loss:0.030057,estimated time:491.81
#  acc:0.9850207926674022
# Epoch:2000,Loss:0.037957,estimated time:394.25
#  acc:0.9863786811508105
# Epoch:3000,Loss:0.022558,estimated time:263.66
#  acc:0.9891793261478401
# Epoch:4000,Loss:0.022476,estimated time:124.29
#  acc:0.9899855724348637
# 2809/2810[(0.9993513, 1175, 2349), (0.99935323, 968, 2108), (0.9993517, 70, 234), (0.9993544, 565, 617), (0.99935466, 1735, 1738), (0.9993549, 2401, 2418), (0.99935347, 1972, 1977), (0.99935585, 1891, 2483), (0.99935526, 1099, 1838), (0.99935704, 1389, 1407)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:8672, 0.64
# False Positve:4894, 0.36
# True Negative:7877640, 1.00
# False Negative:4894, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:10
# train_add:992
# train added: 1000
# current training set length: 24566
# current save path: graphsage_model/graphsage0_10.pth
# Epoch:0,Loss:0.121020,estimated time:637.33
#  acc:0.9618578523162093
# Epoch:1000,Loss:0.021116,estimated time:498.85
#  acc:0.9862004396320118
# Epoch:2000,Loss:0.017863,estimated time:393.77
#  acc:0.9901082797362208
# Epoch:3000,Loss:0.034288,estimated time:253.81
#  acc:0.9883985996906294
# Epoch:4000,Loss:0.014394,estimated time:126.32
#  acc:0.9877065863388423
# 2809/2810[(0.99675995, 1113, 1123), (0.99676776, 72, 2483), (0.9967615, 693, 2668), (0.99677294, 1456, 2155), (0.996774, 950, 1821), (0.9967874, 2031, 2709), (0.99678695, 1114, 2709), (0.9967885, 565, 1109), (0.9967738, 189, 539), (0.9967854, 168, 190)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:9346, 0.69
# False Positve:4220, 0.31
# True Negative:7878314, 1.00
# False Negative:4220, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:11
# train_add:977
# train added: 1000
# current training set length: 25566
# current save path: graphsage_model/graphsage0_11.pth
# Epoch:0,Loss:0.253347,estimated time:702.63
#  acc:0.9457873738559024
# Epoch:1000,Loss:0.022121,estimated time:503.40
#  acc:0.9865446295861692
# Epoch:2000,Loss:0.038507,estimated time:377.66
#  acc:0.9847453649378081
# Epoch:3000,Loss:0.025277,estimated time:258.38
#  acc:0.9875224908081045
# Epoch:4000,Loss:0.024243,estimated time:122.70
#  acc:0.988695924274427
# 2809/2810[(0.99744713, 1049, 1114), (0.99745077, 1695, 2548), (0.9974522, 14, 557), (0.99746835, 134, 575), (0.9974694, 907, 1136), (0.9974611, 693, 1876), (0.9974541, 696, 1022), (0.99747366, 1789, 1796), (0.997479, 399, 413), (0.9975279, 2319, 2337)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:9772, 0.72
# False Positve:3794, 0.28
# True Negative:7878740, 1.00
# False Negative:3794, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:12
# train_add:983
# train added: 1000
# current training set length: 26566
# current save path: graphsage_model/graphsage0_12.pth
# Epoch:0,Loss:0.110877,estimated time:662.16
#  acc:0.9634118798464202
# Epoch:1000,Loss:0.037850,estimated time:494.10
#  acc:0.9853948656177068
# Epoch:2000,Loss:0.029303,estimated time:384.13
#  acc:0.9867123390800271
# Epoch:3000,Loss:0.053779,estimated time:245.14
#  acc:0.9852442972220131
# Epoch:4000,Loss:0.032930,estimated time:129.29
#  acc:0.9893096439057442
# 2809/2810[(0.99201804, 1111, 2460), (0.9920317, 86, 1508), (0.9920333, 1165, 1195), (0.9920391, 1772, 1775), (0.9920353, 696, 1588), (0.9920433, 1770, 1779), (0.9920378, 896, 1933), (0.9921211, 797, 2240), (0.99212354, 2278, 2401), (0.9921113, 48, 2483)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:10100, 0.74
# False Positve:3466, 0.26
# True Negative:7879068, 1.00
# False Negative:3466, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:13
# train_add:994
# train added: 1000
# current training set length: 27566
# current save path: graphsage_model/graphsage0_13.pth
# Epoch:0,Loss:0.123828,estimated time:681.37
#  acc:0.9692737430167597
# Epoch:1000,Loss:0.053318,estimated time:499.51
#  acc:0.9830951171733294
# Epoch:2000,Loss:0.029067,estimated time:415.94
#  acc:0.9865051149967351
# Epoch:3000,Loss:0.037842,estimated time:270.84
#  acc:0.9869041572952187
# Epoch:4000,Loss:0.023468,estimated time:131.23
#  acc:0.9879924544729014
# 2809/2810[(0.9937372, 45, 1123), (0.99373853, 1055, 2704), (0.9937453, 2694, 2695), (0.99378115, 231, 2259), (0.9937435, 33, 109), (0.9937511, 2402, 2547), (0.99378794, 2248, 2255), (0.99380445, 295, 637), (0.9938164, 2093, 2095), (0.9937656, 1112, 2628)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:10654, 0.79
# False Positve:2912, 0.21
# True Negative:7879622, 1.00
# False Negative:2912, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:14
# train_add:986
# train added: 1000
# current training set length: 28566
# current save path: graphsage_model/graphsage0_14.pth
# Epoch:0,Loss:0.125105,estimated time:685.09
#  acc:0.9658335083665897
# Epoch:1000,Loss:0.022405,estimated time:503.30
#  acc:0.9855772596793391
# Epoch:2000,Loss:0.029052,estimated time:381.61
#  acc:0.9845970734439543
# Epoch:3000,Loss:0.047611,estimated time:260.28
#  acc:0.9873625988937899
# Epoch:4000,Loss:0.033155,estimated time:129.37
#  acc:0.9869075124273612
# 2809/2810[(0.9628959, 1809, 2193), (0.96291363, 1226, 2481), (0.9630048, 49, 162), (0.96303225, 2108, 2487), (0.9629408, 241, 2259), (0.9630391, 2250, 2750), (0.9632064, 1962, 1986), (0.9631688, 1104, 1190), (0.96319103, 1404, 2402), (0.96301204, 962, 1422)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:10588, 0.78
# False Positve:2978, 0.22
# True Negative:7879556, 1.00
# False Negative:2978, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:15
# train_add:996
# train added: 1000
# current training set length: 29566
# current save path: graphsage_model/graphsage0_15.pth
# Epoch:0,Loss:0.093192,estimated time:673.31
#  acc:0.9552188324426706
# Epoch:1000,Loss:0.056604,estimated time:514.49
#  acc:0.9844415883108977
# Epoch:2000,Loss:0.021720,estimated time:379.97
#  acc:0.9810593249002232
# Epoch:3000,Loss:0.030566,estimated time:255.97
#  acc:0.9846783467496448
# Epoch:4000,Loss:0.046725,estimated time:129.84
#  acc:0.9873503348440776
# 2809/2810[(0.9359039, 84, 199), (0.93593806, 44, 82), (0.9360423, 1692, 1695), (0.93604, 47, 65), (0.93599373, 542, 2735), (0.93620706, 605, 2616), (0.93651056, 916, 2323), (0.93615943, 49, 2324), (0.93611133, 2036, 2620), (0.9361779, 106, 2363)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11324, 0.83
# False Positve:2242, 0.17
# True Negative:7880292, 1.00
# False Negative:2242, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:16
# train_add:775
# train added: 785
# current training set length: 30351
# current save path: graphsage_model/graphsage0_16.pth
# Epoch:0,Loss:0.118069,estimated time:711.09
#  acc:0.9667885736878521
# Epoch:1000,Loss:0.054306,estimated time:485.58
#  acc:0.9847780962735989
# Epoch:2000,Loss:0.030357,estimated time:390.41
#  acc:0.9837567131231261
# Epoch:3000,Loss:0.052310,estimated time:272.00
#  acc:0.982669434285526
# Epoch:4000,Loss:0.027646,estimated time:127.98
#  acc:0.9887977331883628
# 2809/2810[(0.9704023, 950, 1460), (0.9704668, 738, 1103), (0.97051126, 63, 464), (0.97057813, 1171, 2547), (0.9706771, 614, 2304), (0.9706462, 538, 557), (0.97055864, 562, 2306), (0.9706889, 141, 2440), (0.9710906, 557, 2050), (0.97072643, 1267, 2402)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11500, 0.85
# False Positve:2066, 0.15
# True Negative:7880468, 1.00
# False Negative:2066, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:17
# train_add:991
# train added: 1000
# current training set length: 31351
# current save path: graphsage_model/graphsage0_17.pth
# Epoch:0,Loss:0.210979,estimated time:685.10
#  acc:0.9717393384581035
# Epoch:1000,Loss:0.020842,estimated time:514.89
#  acc:0.9834455041306498
# Epoch:2000,Loss:0.049416,estimated time:388.86
#  acc:0.9844343083155243
# Epoch:3000,Loss:0.027062,estimated time:264.56
#  acc:0.9852636279544512
# Epoch:4000,Loss:0.024303,estimated time:138.13
#  acc:0.9851998341360723
# 2809/28100,Loss:0.037989,estimated time:1.2644[(0.9262008, 1296, 1364), (0.926358, 1076, 1165), (0.92623854, 418, 1702), (0.92681754, 206, 2259), (0.9270415, 1261, 2722), (0.9263384, 2372, 2604), (0.92652845, 84, 92), (0.927192, 1435, 1933), (0.92687774, 63, 68), (0.9280189, 1, 2498)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11554, 0.85
# False Positve:2012, 0.15
# True Negative:7880522, 1.00
# False Negative:2012, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:18
# train_add:657
# train added: 663
# current training set length: 32014
# current save path: graphsage_model/graphsage0_18.pth
# Epoch:0,Loss:0.059829,estimated time:640.56
#  acc:0.9727619166614606
# Epoch:1000,Loss:0.056100,estimated time:500.48
#  acc:0.9865059036671456
# Epoch:2000,Loss:0.087093,estimated time:382.50
#  acc:0.9863809583307303
# Epoch:3000,Loss:0.037304,estimated time:256.37
#  acc:0.987536702692572
# Epoch:4000,Loss:0.070857,estimated time:125.41
#  acc:0.9878803023677142
# 2809/2810[(0.9435438, 1195, 2280), (0.9435458, 1159, 2573), (0.944084, 1581, 1668), (0.9440763, 47, 1563), (0.94361925, 2053, 2594), (0.94460744, 1728, 2672), (0.94421744, 216, 315), (0.9444686, 1812, 1959), (0.9449124, 1046, 1206), (0.944273, 290, 739)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11802, 0.87
# False Positve:1764, 0.13
# True Negative:7880770, 1.00
# False Negative:1764, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:19
# train_add:723
# train added: 727
# current training set length: 32741
# current save path: graphsage_model/graphsage0_19.pth
# Epoch:0,Loss:0.059878,estimated time:660.86
#  acc:0.9706484224672429
# Epoch:1000,Loss:0.017902,estimated time:500.57
#  acc:0.9813383830671024
# Epoch:2000,Loss:0.041585,estimated time:380.06
#  acc:0.9852783971167649
# Epoch:3000,Loss:0.026178,estimated time:259.63
#  acc:0.986469564155035
# Epoch:4000,Loss:0.022858,estimated time:124.09
#  acc:0.9867749916007452
# 2809/2810[(0.9298516, 714, 1820), (0.9299106, 1110, 2607), (0.9300768, 1402, 2197), (0.93009377, 309, 463), (0.93009377, 309, 458), (0.93015474, 1802, 2030), (0.9305371, 593, 599), (0.93080014, 1090, 1110), (0.93024427, 1581, 2247), (0.93041617, 401, 501)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12142, 0.90
# False Positve:1424, 0.10
# True Negative:7881110, 1.00
# False Negative:1424, 0.00
# Positive:0.00
# Negative:1.00

# %%
# if you want to do reboost
graphsagemodel.load_model(path='graphsage_model/graphsage.pth',embedding_path='graphsage_model/embeddings.npy')

# %%
graphsagemodel.graphsage_train(boost_times=20,add_edges=2000,training_epoch=1500,
                               boost_epoch=2500,learning_rate=0.001,save_number=1)
graphsagemodel.save_model(path='graphsage_model/graphsage.pth',embedding_path='graphsage_model/embeddings.npy')
# Out:
# 3946645
# 6783
# -13566
# Training GraphSAGE model
# Epoch:0,Loss:0.011323,estimated time:214.51
#  acc:0.9965354562877783
# Epoch:1000,Loss:0.000810,estimated time:64.95
#  acc:0.9988942945599293
# 2809/2810[(0.99999833, 215, 240), (0.99999833, 242, 265), (0.99999833, 268, 1704), (0.99999833, 525, 611), (0.99999833, 274, 1803), (0.99999833, 322, 401), (0.99999833, 338, 2297), (0.99999833, 614, 1973), (0.99999833, 591, 602), (0.99999833, 695, 1127)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:8268, 0.61
# False Positve:5298, 0.39
# True Negative:7877236, 1.00
# False Negative:5298, 0.00
# Positive:0.00
# Negative:1.00
# Start boosting
# boost iter:0
# train_add:1910
# train added: 2000
# current training set length: 15566
# current save path: graphsage_model/graphsage1_0.pth
# Epoch:0,Loss:0.596455,estimated time:332.45
#  acc:0.9456507773352177
# Epoch:1000,Loss:0.022503,estimated time:199.94
#  acc:0.9958884748811512
# Epoch:2000,Loss:0.009244,estimated time:60.912
#  acc:0.9968521135808814
# 2809/2810[(0.9999162, 1, 2036), (0.9999162, 858, 861), (0.9999162, 147, 2454), (0.99991643, 1446, 1971), (0.9999167, 59, 89), (0.9999169, 1389, 1407), (0.9999167, 537, 2802), (0.99991703, 512, 1866), (0.9999188, 834, 2136), (0.9999168, 122, 2448)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:9458, 0.70
# False Positve:4108, 0.30
# True Negative:7878426, 1.00
# False Negative:4108, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:1
# train_add:1949
# train added: 2000
# current training set length: 17566
# current save path: graphsage_model/graphsage1_1.pth
# Epoch:0,Loss:0.356933,estimated time:338.57
#  acc:0.9561653193669589
# Epoch:1000,Loss:0.019653,estimated time:189.00
#  acc:0.9915177046567232
# Epoch:2000,Loss:0.041599,estimated time:63.167
#  acc:0.9923716270067175
# 2809/28100,Loss:0.042840,estimated time:1.354[(0.9997049, 282, 353), (0.999706, 1505, 2309), (0.99970526, 189, 1793), (0.9997069, 171, 2347), (0.99970776, 434, 445), (0.9997054, 32, 1787), (0.99970835, 47, 1427), (0.9997075, 1536, 2096), (0.9997074, 379, 438), (0.999708, 2372, 2704)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:9970, 0.73
# False Positve:3596, 0.27
# True Negative:7878938, 1.00
# False Negative:3596, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:2
# train_add:1975
# train added: 2000
# current training set length: 19566
# current save path: graphsage_model/graphsage1_2.pth
# Epoch:0,Loss:0.185150,estimated time:337.23
#  acc:0.96131043647143
# Epoch:1000,Loss:0.039100,estimated time:189.17
#  acc:0.9906470407850353
# Epoch:2000,Loss:0.026406,estimated time:64.555
#  acc:0.9897270775835634
# 2809/2810[(0.9919355, 254, 279), (0.9919355, 254, 340), (0.991947, 2793, 2795), (0.9919715, 530, 542), (0.99211603, 300, 348), (0.9919864, 852, 939), (0.9920365, 466, 1703), (0.99201864, 551, 2305), (0.99202406, 62, 1787), (0.9921524, 147, 1506)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11300, 0.83
# False Positve:2266, 0.17
# True Negative:7880268, 1.00
# False Negative:2266, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:3
# train_add:1586
# train added: 1597
# current training set length: 21163
# current save path: graphsage_model/graphsage1_3.pth
# Epoch:0,Loss:0.168011,estimated time:345.97
#  acc:0.9530784860369513
# Epoch:1000,Loss:0.012324,estimated time:198.18
#  acc:0.9881869300193734
# Epoch:2000,Loss:0.023046,estimated time:63.524
#  acc:0.9886594528185985
# 2809/2810[(0.9877159, 59, 1759), (0.98772675, 478, 2470), (0.98777753, 493, 954), (0.9877396, 1319, 1323), (0.98781383, 0, 1474), (0.98784465, 271, 501), (0.98778886, 1094, 2481), (0.9878347, 2095, 2543), (0.98798776, 557, 1976), (0.98792136, 1091, 2216)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11758, 0.87
# False Positve:1808, 0.13
# True Negative:7880726, 1.00
# False Negative:1808, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:4
# train_add:1160
# train added: 1167
# current training set length: 22330
# current save path: graphsage_model/graphsage1_4.pth
# Epoch:0,Loss:0.053518,estimated time:345.68
#  acc:0.9622480967308553
# Epoch:1000,Loss:0.047875,estimated time:201.84
#  acc:0.9841916703985669
# Epoch:2000,Loss:0.032492,estimated time:64.832
#  acc:0.9893864755933721
# 2809/2810[(0.97435206, 358, 447), (0.97442734, 892, 2663), (0.9745885, 676, 834), (0.97451836, 1222, 1533), (0.9744949, 59, 2346), (0.9749451, 2591, 2596), (0.9747487, 410, 2383), (0.97464275, 611, 1792), (0.97472954, 1763, 1775), (0.9745728, 1902, 2458)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:11796, 0.87
# False Positve:1770, 0.13
# True Negative:7880764, 1.00
# False Negative:1770, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:5
# train_add:872
# train added: 885
# current training set length: 23215
# current save path: graphsage_model/graphsage1_5.pth
# Epoch:0,Loss:0.103691,estimated time:334.95
#  acc:0.9715270299375404
# Epoch:1000,Loss:0.071416,estimated time:199.79
#  acc:0.9871203962954986
# Epoch:2000,Loss:0.023162,estimated time:64.425
#  acc:0.9847943140211071
# 2809/2810[(0.95971644, 380, 381), (0.95974344, 597, 1778), (0.9597756, 1190, 2520), (0.9598154, 1131, 2116), (0.95990074, 615, 1446), (0.95996106, 1962, 1964), (0.9600683, 614, 2311), (0.96051985, 1628, 1758), (0.9599565, 867, 905), (0.9599603, 1416, 2039)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12108, 0.89
# False Positve:1458, 0.11
# True Negative:7881076, 1.00
# False Negative:1458, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:6
# train_add:697
# train added: 701
# current training set length: 23916
# current save path: graphsage_model/graphsage1_6.pth
# Epoch:0,Loss:0.066733,estimated time:339.40
#  acc:0.9749540056865696
# Epoch:1000,Loss:0.062992,estimated time:193.06
#  acc:0.9828984780063555
# Epoch:2000,Loss:0.064493,estimated time:64.916
#  acc:0.9859926409098512
# 2809/2810[(0.94199747, 1793, 2560), (0.9420291, 96, 1718), (0.94215286, 1318, 1749), (0.94224095, 2036, 2100), (0.94248676, 1405, 1406), (0.94227725, 84, 2354), (0.94260865, 1707, 2487), (0.9426361, 1547, 2398), (0.9422526, 245, 640), (0.9428165, 1348, 1793)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12066, 0.89
# False Positve:1500, 0.11
# True Negative:7881034, 1.00
# False Negative:1500, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:7
# train_add:627
# train added: 632
# current training set length: 24548
# current save path: graphsage_model/graphsage1_7.pth
# Epoch:0,Loss:0.052738,estimated time:338.45
#  acc:0.9751507251099886
# Epoch:1000,Loss:0.022015,estimated time:193.79
#  acc:0.9835831839661072
# Epoch:2000,Loss:0.031108,estimated time:62.711
#  acc:0.9881864102981913
# 2809/2810[(0.9506354, 856, 1707), (0.9507181, 1052, 2783), (0.95074147, 1894, 1963), (0.9507262, 66, 1426), (0.95078534, 1695, 2473), (0.95106345, 2771, 2775), (0.95173913, 580, 2643), (0.9508483, 717, 1561), (0.9510915, 34, 1432), (0.9509264, 627, 1457)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12244, 0.90
# False Positve:1322, 0.10
# True Negative:7881212, 1.00
# False Negative:1322, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:8
# train_add:648
# train added: 660
# current training set length: 25208
# current save path: graphsage_model/graphsage1_8.pth
# Epoch:0,Loss:0.051271,estimated time:356.70
#  acc:0.9751269438273564
# Epoch:1000,Loss:0.014010,estimated time:202.13
#  acc:0.9858774992066011
# Epoch:2000,Loss:0.042659,estimated time:72.436
#  acc:0.9861155188828943
# 2809/2810[(0.9385668, 86, 103), (0.9388596, 101, 2259), (0.93867606, 565, 2376), (0.9389221, 42, 1439), (0.9390745, 1020, 1652), (0.9387768, 852, 2508), (0.9387568, 1881, 1900), (0.93900883, 86, 606), (0.9393427, 1289, 1747), (0.93939465, 4, 430)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12320, 0.91
# False Positve:1246, 0.09
# True Negative:7881288, 1.00
# False Negative:1246, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:9
# train_add:521
# train added: 524
# current training set length: 25732
# current save path: graphsage_model/graphsage1_9.pth
# Epoch:0,Loss:0.078519,estimated time:349.30
#  acc:0.9800637338722213
# Epoch:1000,Loss:0.026396,estimated time:202.42
#  acc:0.9843385667651173
# Epoch:2000,Loss:0.029454,estimated time:64.338
#  acc:0.9869034665008549
# 2809/2810[(0.93464863, 2019, 2022), (0.9347377, 131, 141), (0.93478996, 103, 121), (0.9352825, 125, 440), (0.9348742, 27, 731), (0.93525815, 1385, 2336), (0.93624413, 2215, 2402), (0.9356952, 2017, 2691), (0.9356606, 646, 2407), (0.9349604, 2111, 2618)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12338, 0.91
# False Positve:1228, 0.09
# True Negative:7881306, 1.00
# False Negative:1228, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:10
# train_add:504
# train added: 511
# current training set length: 26243
# current save path: graphsage_model/graphsage1_10.pth
# Epoch:0,Loss:0.096437,estimated time:323.38
#  acc:0.9752695957017109
# Epoch:1000,Loss:0.015120,estimated time:199.77
#  acc:0.9860534237701483
# Epoch:2000,Loss:0.057438,estimated time:65.640
#  acc:0.9831574134054796
# 2809/2810[(0.87575614, 1021, 2483), (0.8760855, 917, 1035), (0.87591016, 170, 189), (0.87736374, 907, 2546), (0.8764301, 73, 290), (0.87652546, 62, 173), (0.87647974, 671, 1461), (0.87762535, 978, 1973), (0.87794423, 352, 1440), (0.87648916, 584, 1112)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12534, 0.92
# False Positve:1032, 0.08
# True Negative:7881502, 1.00
# False Negative:1032, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:11
# train_add:314
# train added: 320
# current training set length: 26563
# current save path: graphsage_model/graphsage1_11.pth
# Epoch:0,Loss:0.045868,estimated time:362.64
#  acc:0.98339795956782
# Epoch:1000,Loss:0.038008,estimated time:205.61
#  acc:0.9876519971388774
# Epoch:2000,Loss:0.069408,estimated time:67.731
#  acc:0.9849414599254602
# 2809/2810[(0.74695706, 1190, 2605), (0.74781185, 1657, 2109), (0.7477243, 132, 1153), (0.74889934, 124, 189), (0.7495405, 110, 143), (0.75010186, 525, 556), (0.75166535, 608, 2418), (0.7572723, 1049, 1140), (0.7522025, 349, 2440), (0.7515034, 88, 1678)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12704, 0.94
# False Positve:862, 0.06
# True Negative:7881672, 1.00
# False Negative:862, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:12
# train_add:193
# train added: 198
# current training set length: 26761
# current save path: graphsage_model/graphsage1_12.pth
# Epoch:0,Loss:0.077465,estimated time:329.64
#  acc:0.9686484062628452
# Epoch:1000,Loss:0.040977,estimated time:192.67
#  acc:0.984305519225739
# Epoch:2000,Loss:0.018223,estimated time:64.109
#  acc:0.9894622771944247
# 2809/2810[(0.77906036, 1057, 2171), (0.7790846, 1429, 2052), (0.7798356, 1637, 2031), (0.7838306, 519, 628), (0.77994454, 512, 935), (0.7829691, 1718, 2483), (0.78147453, 5, 1195), (0.7864171, 565, 2430), (0.78760564, 349, 398), (0.77996457, 1131, 2700)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12630, 0.93
# False Positve:936, 0.07
# True Negative:7881598, 1.00
# False Negative:936, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:13
# train_add:195
# train added: 198
# current training set length: 26959
# current save path: graphsage_model/graphsage1_13.pth
# Epoch:0,Loss:0.042367,estimated time:325.41
#  acc:0.9828999591972996
# Epoch:1000,Loss:0.064393,estimated time:200.72
#  acc:0.9870544159649839
# Epoch:2000,Loss:0.024113,estimated time:71.575
#  acc:0.9887978040728513
# 2809/28100,Loss:0.025589,estimated time:1.274[(0.8470815, 58, 162), (0.8477331, 954, 1565), (0.8475379, 33, 108), (0.8490788, 284, 501), (0.8504114, 1049, 1140), (0.85004175, 928, 1419), (0.8492774, 31, 123), (0.84989285, 205, 256), (0.8503675, 4, 333), (0.8515605, 86, 2322)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12712, 0.94
# False Positve:854, 0.06
# True Negative:7881680, 1.00
# False Negative:854, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:14
# train_add:210
# train added: 212
# current training set length: 27171
# current save path: graphsage_model/graphsage1_14.pth
# Epoch:0,Loss:0.031453,estimated time:356.19
#  acc:0.962533583600162
# Epoch:1000,Loss:0.054506,estimated time:198.69
#  acc:0.9881123256413088
# Epoch:2000,Loss:0.033607,estimated time:64.656
#  acc:0.9868977954436715
# 2809/2810[(0.8427651, 499, 1933), (0.8450468, 286, 502), (0.8431229, 670, 1802), (0.84572643, 2210, 2259), (0.84589493, 1291, 1476), (0.8457514, 2125, 2573), (0.8443855, 1772, 1777), (0.8466372, 1366, 1745), (0.84837204, 53, 174), (0.84592754, 176, 898)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12568, 0.93
# False Positve:998, 0.07
# True Negative:7881536, 1.00
# False Negative:998, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:15
# train_add:280
# train added: 283
# current training set length: 27454
# current save path: graphsage_model/graphsage1_15.pth
# Epoch:0,Loss:0.051277,estimated time:335.55
#  acc:0.97854593137612
# Epoch:1000,Loss:0.028744,estimated time:194.75
#  acc:0.9855030232388723
# Epoch:2000,Loss:0.018241,estimated time:65.006
#  acc:0.9881620164639032
# 2809/2810[(0.8167833, 1808, 1976), (0.81687003, 1063, 2349), (0.81767046, 2593, 2595), (0.8172268, 89, 1341), (0.8172524, 443, 444), (0.8192581, 33, 1969), (0.81801087, 859, 1094), (0.81836534, 281, 1787), (0.81746227, 556, 2570), (0.8227592, 2274, 2618)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12574, 0.93
# False Positve:992, 0.07
# True Negative:7881542, 1.00
# False Negative:992, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:16
# train_add:236
# train added: 236
# current training set length: 27690
# current save path: graphsage_model/graphsage1_16.pth
# Epoch:0,Loss:0.072414,estimated time:354.59
#  acc:0.9852654387865656
# Epoch:1000,Loss:0.034150,estimated time:194.55
#  acc:0.9869266883351391
# Epoch:2000,Loss:0.046219,estimated time:60.656
#  acc:0.9894185626579993
# 2809/2810[(0.6110792, 138, 1565), (0.61234486, 1402, 2618), (0.61325735, 202, 2355), (0.61375225, 328, 2692), (0.61287093, 558, 2571), (0.6134451, 249, 308), (0.62113804, 1902, 2467), (0.6205396, 917, 1887), (0.61471087, 4, 372), (0.6139866, 103, 132)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12660, 0.93
# False Positve:906, 0.07
# True Negative:7881628, 1.00
# False Negative:906, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:17
# train_add:117
# train added: 118
# current training set length: 27808
# current save path: graphsage_model/graphsage1_17.pth
# Epoch:0,Loss:0.056932,estimated time:336.35
#  acc:0.9865506329113924
# Epoch:1000,Loss:0.060324,estimated time:186.98
#  acc:0.98942750287687
# Epoch:2000,Loss:0.028717,estimated time:62.683
#  acc:0.9901467203682394
# 2809/2810[(0.8142528, 278, 443), (0.814711, 747, 957), (0.814666, 119, 234), (0.81602204, 1498, 1762), (0.8163181, 411, 486), (0.8149674, 200, 1687), (0.82094723, 554, 2547), (0.8213017, 180, 571), (0.81664646, 540, 968), (0.8217632, 1013, 1870)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12648, 0.93
# False Positve:918, 0.07
# True Negative:7881616, 1.00
# False Negative:918, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:18
# train_add:256
# train added: 260
# current training set length: 28068
# current save path: graphsage_model/graphsage1_18.pth
# Epoch:0,Loss:0.029944,estimated time:324.26
#  acc:0.973492945703292
# Epoch:1000,Loss:0.048438,estimated time:194.81
#  acc:0.9864970785235856
# Epoch:2000,Loss:0.027925,estimated time:63.776
#  acc:0.9899173435941285
# 2809/2810[(0.7455027, 581, 2036), (0.7459838, 386, 452), (0.74705464, 241, 789), (0.74958706, 113, 134), (0.74738663, 540, 1319), (0.74765337, 1853, 1854), (0.7472046, 2122, 2513), (0.7587843, 556, 2547), (0.75046, 282, 2259), (0.75215006, 829, 1538)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12446, 0.92
# False Positve:1120, 0.08
# True Negative:7881414, 1.00
# False Negative:1120, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:19
# train_add:197
# train added: 199
# current training set length: 28267
# current save path: graphsage_model/graphsage1_19.pth
# Epoch:0,Loss:0.100349,estimated time:351.83
#  acc:0.9814978596950508
# Epoch:1000,Loss:0.025675,estimated time:196.18
#  acc:0.9887147557222202
# Epoch:2000,Loss:0.042219,estimated time:69.011
#  acc:0.9886793787809106
# 2809/2810[(0.91342026, 727, 809), (0.9136043, 236, 2412), (0.9136486, 1309, 1388), (0.91441816, 86, 2355), (0.91366196, 907, 1174), (0.9137534, 2628, 2630), (0.91442984, 290, 2483), (0.9146077, 803, 1444), (0.9157859, 1268, 1892), (0.91566205, 2113, 2122)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12764, 0.94
# False Positve:802, 0.06
# True Negative:7881732, 1.00
# False Negative:802, 0.00
# Positive:0.00
# Negative:1.00

# %% [markdown]
# # *1.2 Load pretrained model*

# %%
graphsagemodel.load_model(path='graphsage_model/graphsage.pth',embedding_path='graphsage_model/embeddings.npy')

# %%
embedding_matrix_numpy=graphsagemodel.embedding_matrix_numpy
link_prediction_model=graphsagemodel.graphsage_link_prediction_from_embedding_one_to_other
predict_adj=utils.evaluate_overlap_torch(_N=_N,
                                                    _num_of_edges=_num_of_edges,
                                                    adj_origin=adj_origin,
                                                    embedding_matrix_numpy=embedding_matrix_numpy,
                                                    link_prediction_from_embedding_one_to_other=link_prediction_model)
# Out:
# 2809/2810[(0.9160829, 70, 2259), (0.91639525, 328, 1435), (0.9161416, 335, 1435), (0.9166448, 533, 558), (0.91692716, 1383, 2055), (0.9164858, 4, 444), (0.9167271, 1801, 2275), (0.9216437, 33, 59), (0.9177841, 1276, 1315), (0.91878307, 118, 1810)]
# 1.0
# (2810, 2810)
# 13566
# 13566
# True Positve:12828, 0.95
# False Positve:738, 0.05
# True Negative:7881796, 1.00
# False Negative:738, 0.00
# Positive:0.00
# Negative:1.00

# %%
metric_embedding=utils.compute_graph_statistics(predict_adj)
metric_origin=utils.compute_graph_statistics(adj_origin)
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# /opt/anaconda3/lib/python3.7/site-packages/powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))

# %%
for x in metric_origin:
    print('%-25s origin:%17.8f, link_pred:%17.8f'%(x,metric_origin[x],metric_embedding[x]))
# Out:
# d_max                     origin:     240.00000000, link_pred:     223.00000000
# d_min                     origin:       1.00000000, link_pred:       0.00000000
# d                         origin:       4.82775801, link_pred:       4.82775801
# LCC                       origin:    2810.00000000, link_pred:    2795.00000000
# wedge_count               origin:  101872.00000000, link_pred:   97846.00000000
# claw_count                origin: 3094240.00000000, link_pred: 2650529.00000000
# triangle_count            origin:    2814.00000000, link_pred:    2690.00000000
# square_count              origin:     517.00000000, link_pred:     500.00000000
# power_law_exp             origin:       1.85595899, link_pred:       1.84427874
# gini                      origin:       0.48239581, link_pred:       0.47711428
# rel_edge_distr_entropy    origin:       0.94070677, link_pred:       0.94198854
# assortativity             origin:      -0.07543032, link_pred:      -0.07591085
# clustering_coefficient    origin:       0.00272830, link_pred:       0.00304468
# n_components              origin:       1.00000000, link_pred:      15.00000000
# cpl                       origin:       5.60937302, link_pred:       5.54658742
