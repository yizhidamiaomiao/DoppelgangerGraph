# %%
import networkx as nx
import scipy.sparse as sp
import numpy as np
import utils
import torch
import torch
from collections import defaultdict
import numpy as np
import time
import json

# %%
seed=114514
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.seed_all()

# %% [markdown]
# # **Read data**

# %%
loader = np.load('citeseer.npz')
train_ones = loader['edges']
print(len(train_ones))
print(train_ones[:5])
# Out:
# 7358
# [[1370  823]
#  [  65   63]
#  [ 262  247]
#  [ 398  308]
#  [ 859  383]]

# %%
adj_sparse = np.zeros((np.max(train_ones)+1,np.max(train_ones)+1))
for e in train_ones:
    adj_sparse[e[0],e[1]]=1
    adj_sparse[e[1],e[0]]=1
    
adj_sparse = sp.coo_matrix(adj_sparse).tocsr()

lcc = graph_utils.largest_connected_components(adj_sparse)
adj_sparse= adj_sparse[lcc,:][:,lcc]
_N = adj_sparse.shape[0]
print('n',_N)
_Edges=[]
for x in np.column_stack(adj_sparse.nonzero()):
    if not x[0]==x[1]:
        _Edges.append((x[0],x[1]))
_num_of_edges=int(len(_Edges)/2)
print('m',_num_of_edges)

dic=defaultdict(set)
for x in _Edges:
    a1=x[0]
    a2=x[1]
    dic[a1].add(a2)
    dic[a2].add(a1)
    

adj_origin=np.zeros((_N,_N)).astype(int)
for (i,j) in _Edges:
    adj_origin[i][j]=1
    adj_origin[j][i]=1
assert(np.sum(adj_origin==adj_origin.T)==_N*_N)
assert(np.sum(adj_origin)==_num_of_edges*2)
# Out:
# Selecting 1 largest connected components
# n 2120
# m 3679

# %% [markdown]
# # **1.Get link prediction model and embedding**

# %%
embedding_dim=128

graphsagemodel=graph_utils.GraphSAGE(_N=_N,_M=_num_of_edges,adj_origin=adj_origin,
                                         adj_dic=dic,embedding_dim=embedding_dim)

# %% [markdown]
# # *1.1 Training step*

# %%
graphsagemodel.graphsage_train(boost_times=20,add_edges=1000,training_epoch=2500,
                               boost_epoch=4000,learning_rate=0.001,save_number=0)
graphsagemodel.save_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')
# Out:
# 2246140
# 3679
# -7358
# Training GraphSAGE model
# Epoch:0,Loss:0.693546,estimated time:681.26
#  acc:0.5
# Epoch:1000,Loss:0.010743,estimated time:122.32
#  acc:0.9976895895623811
# Epoch:2000,Loss:0.001174,estimated time:35.165
#  acc:0.9979614025550422
# 2119/2120[(1.0, 0, 1), (1.0, 0, 2), (1.0, 0, 199), (1.0, 0, 38), (1.0, 0, 10), (1.0, 0, 217), (1.0, 0, 471), (1.0, 0, 129), (1.0, 0, 156), (1.0, 0, 162)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:434, 0.06
# False Positve:6924, 0.94
# True Negative:4480118, 1.00
# False Negative:6924, 0.00
# Positive:0.00
# Negative:1.00
# Start boosting
# boost iter:0
# train_add:0
# train added: 1000
# current training set length: 8358
# current save path: graphsage_model/graphsage0_0.pth
# Epoch:0,Loss:1.171569,estimated time:293.89
#  acc:0.9167264895908112
# Epoch:1000,Loss:0.021134,estimated time:224.63
#  acc:0.9956927494615937
# Epoch:2000,Loss:0.013122,estimated time:197.37
#  acc:0.994256999282125
# Epoch:3000,Loss:0.000916,estimated time:74.615
#  acc:0.998205312275664
# 2119/2120[(1.0, 0, 1), (1.0, 0, 2), (1.0, 0, 3), (1.0, 0, 8), (1.0, 0, 10), (1.0, 0, 429), (1.0, 0, 7), (1.0, 0, 64), (1.0, 0, 9), (1.0, 0, 351)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:1028, 0.14
# False Positve:6330, 0.86
# True Negative:4480712, 1.00
# False Negative:6330, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:1
# train_add:586
# train added: 1000
# current training set length: 9358
# current save path: graphsage_model/graphsage0_1.pth
# Epoch:0,Loss:0.498140,estimated time:307.23
#  acc:0.9320367599914512
# Epoch:1000,Loss:0.012965,estimated time:218.14
#  acc:0.9932677922633041
# Epoch:2000,Loss:0.007807,estimated time:155.88
#  acc:0.9955118615088694
# Epoch:3000,Loss:0.006063,estimated time:75.680
#  acc:0.9957255823893995
# 2119/2120[(0.9999999, 204, 1881), (0.9999999, 206, 209), (0.9999999, 206, 1432), (0.9999999, 208, 1317), (0.9999999, 206, 1953), (0.9999999, 217, 361), (0.9999999, 218, 655), (0.9999999, 209, 1029), (0.9999999, 217, 478), (0.9999999, 213, 2065)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:1546, 0.21
# False Positve:5812, 0.79
# True Negative:4481230, 1.00
# False Negative:5812, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:2
# train_add:974
# train added: 1000
# current training set length: 10358
# current save path: graphsage_model/graphsage0_2.pth
# Epoch:0,Loss:0.441028,estimated time:310.19
#  acc:0.9396601660552231
# Epoch:1000,Loss:0.051016,estimated time:223.97
#  acc:0.9913110639119521
# Epoch:2000,Loss:0.026242,estimated time:147.03
#  acc:0.9937246572697432
# Epoch:3000,Loss:0.014953,estimated time:74.875
#  acc:0.9944970071442364
# 2119/2120[(0.99999964, 1360, 1863), (0.99999964, 1394, 1895), (0.99999964, 1402, 1660), (0.99999964, 1498, 1977), (0.99999964, 1473, 1975), (0.99999964, 1412, 2099), (0.99999964, 1470, 1473), (0.99999964, 1540, 1714), (0.99999964, 1603, 1646), (0.99999976, 8, 517)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:1622, 0.22
# False Positve:5736, 0.78
# True Negative:4481306, 1.00
# False Negative:5736, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:3
# train_add:773
# train added: 1000
# current training set length: 11358
# current save path: graphsage_model/graphsage0_3.pth
# Epoch:0,Loss:0.323988,estimated time:279.56
#  acc:0.9455009684803662
# Epoch:1000,Loss:0.059214,estimated time:227.63
#  acc:0.9880260609262194
# Epoch:2000,Loss:0.027417,estimated time:146.66
#  acc:0.992428244409227
# Epoch:3000,Loss:0.005439,estimated time:74.272
#  acc:0.9953336855080119
# 2119/2120[(0.99998975, 1144, 1787), (0.99998987, 154, 667), (0.99998975, 1400, 1455), (0.99998987, 490, 686), (0.99998987, 358, 2114), (0.99998987, 302, 1135), (0.99998987, 495, 753), (0.99999, 158, 1679), (0.99998987, 870, 1097), (0.99999, 101, 421)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:2298, 0.31
# False Positve:5060, 0.69
# True Negative:4481982, 1.00
# False Negative:5060, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:4
# train_add:973
# train added: 1000
# current training set length: 12358
# current save path: graphsage_model/graphsage0_4.pth
# Epoch:0,Loss:0.649376,estimated time:320.40
#  acc:0.9364783945622269
# Epoch:1000,Loss:0.032376,estimated time:218.54
#  acc:0.9908561255866645
# Epoch:2000,Loss:0.005595,estimated time:149.42
#  acc:0.9915034795274317
# Epoch:3000,Loss:0.050984,estimated time:72.337
#  acc:0.9896423369477262
# 2119/2120[(0.9999876, 513, 1375), (0.9999876, 962, 1510), (0.9999876, 938, 951), (0.9999877, 188, 255), (0.9999876, 1009, 1563), (0.9999877, 55, 450), (0.9999877, 1246, 1338), (0.99998796, 1092, 1159), (0.9999877, 697, 2101), (0.99998784, 511, 512)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:2884, 0.39
# False Positve:4474, 0.61
# True Negative:4482568, 1.00
# False Negative:4474, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:5
# train_add:932
# train added: 1000
# current training set length: 13358
# current save path: graphsage_model/graphsage0_5.pth
# Epoch:0,Loss:0.316724,estimated time:309.98
#  acc:0.9600988171882018
# Epoch:1000,Loss:0.036680,estimated time:222.25
#  acc:0.9908668962419523
# Epoch:2000,Loss:0.024329,estimated time:150.49
#  acc:0.9946099715526276
# Epoch:3000,Loss:0.024082,estimated time:72.857
#  acc:0.9920646803413685
# 2119/2120[(0.9998258, 871, 1165), (0.9998258, 1013, 1653), (0.9998264, 880, 1327), (0.9998267, 39, 260), (0.99982613, 653, 863), (0.9998267, 472, 1487), (0.9998265, 931, 938), (0.99982685, 1590, 2046), (0.9998275, 1740, 1900), (0.9998286, 604, 1485)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:3414, 0.46
# False Positve:3944, 0.54
# True Negative:4483098, 1.00
# False Negative:3944, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:6
# train_add:971
# train added: 1000
# current training set length: 14358
# current save path: graphsage_model/graphsage0_6.pth
# Epoch:0,Loss:0.208189,estimated time:317.41
#  acc:0.9433068672517063
# Epoch:1000,Loss:0.035990,estimated time:207.41
#  acc:0.9903189859311882
# Epoch:2000,Loss:0.021796,estimated time:150.17
#  acc:0.9921298230951386
# Epoch:3000,Loss:0.030761,estimated time:71.851
#  acc:0.9924780610112829
# 2119/2120[(0.99898404, 1064, 1923), (0.99898463, 397, 1138), (0.9989864, 1246, 1894), (0.998985, 138, 267), (0.9989895, 59, 2046), (0.9989868, 1009, 1239), (0.99899286, 1847, 2104), (0.9990018, 186, 1315), (0.999, 333, 334), (0.9990276, 787, 1315)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:4470, 0.61
# False Positve:2888, 0.39
# True Negative:4484154, 1.00
# False Negative:2888, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:7
# train_add:986
# train added: 1000
# current training set length: 15358
# current save path: graphsage_model/graphsage0_7.pth
# Epoch:0,Loss:0.357900,estimated time:320.91
#  acc:0.9510352910535226
# Epoch:1000,Loss:0.020606,estimated time:231.13
#  acc:0.9856752181273604
# Epoch:2000,Loss:0.026756,estimated time:149.29
#  acc:0.9884750618570126
# Epoch:3000,Loss:0.030365,estimated time:93.223
#  acc:0.9893866388852716
# 2119/2120[(0.9992662, 202, 454), (0.9992669, 1507, 2037), (0.99926656, 1552, 1553), (0.999273, 740, 2036), (0.9992687, 411, 1494), (0.999271, 110, 1315), (0.9992725, 21, 707), (0.9992842, 244, 764), (0.9992756, 143, 1702), (0.999271, 14, 723)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:4898, 0.67
# False Positve:2460, 0.33
# True Negative:4484582, 1.00
# False Negative:2460, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:8
# train_add:982
# train added: 1000
# current training set length: 16358
# current save path: graphsage_model/graphsage0_8.pth
# Epoch:0,Loss:0.315596,estimated time:327.34
#  acc:0.9672331580877858
# Epoch:1000,Loss:0.011725,estimated time:252.26
#  acc:0.988568284631373
# Epoch:2000,Loss:0.075454,estimated time:161.48
#  acc:0.9920528181929331
# Epoch:3000,Loss:0.014332,estimated time:74.517
#  acc:0.9929086685413865
# 2119/2120[(0.99369496, 1144, 1145), (0.9936965, 993, 995), (0.9937773, 93, 2014), (0.9938399, 184, 1258), (0.99379385, 352, 1682), (0.9938308, 522, 1990), (0.9937961, 430, 431), (0.99385285, 109, 1305), (0.993848, 318, 1473), (0.99382836, 802, 805)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:5678, 0.77
# False Positve:1680, 0.23
# True Negative:4485362, 1.00
# False Negative:1680, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:9
# train_add:990
# train added: 1000
# current training set length: 17358
# current save path: graphsage_model/graphsage0_9.pth
# Epoch:0,Loss:0.324567,estimated time:327.61
#  acc:0.9635902753773476
# Epoch:1000,Loss:0.031134,estimated time:232.06
#  acc:0.9873833390943657
# Epoch:2000,Loss:0.009660,estimated time:168.65
#  acc:0.9904366862541768
# Epoch:3000,Loss:0.012763,estimated time:80.849
#  acc:0.9898029726927066
# 2119/2120[(0.99273527, 495, 750), (0.99274844, 122, 1898), (0.99278283, 184, 924), (0.99284005, 1344, 1560), (0.9928375, 1669, 1700), (0.99281305, 334, 922), (0.9928685, 242, 524), (0.99322236, 580, 1007), (0.9929311, 247, 825), (0.99287874, 762, 1660)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:5838, 0.79
# False Positve:1520, 0.21
# True Negative:4485522, 1.00
# False Negative:1520, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:10
# train_add:998
# train added: 1000
# current training set length: 18358
# current save path: graphsage_model/graphsage0_10.pth
# Epoch:0,Loss:0.193779,estimated time:329.00
#  acc:0.9672077568362567
# Epoch:1000,Loss:0.036236,estimated time:225.82
#  acc:0.9865998474779387
# Epoch:2000,Loss:0.012826,estimated time:155.54
#  acc:0.9901950103497112
# Epoch:3000,Loss:0.039815,estimated time:81.014
#  acc:0.9889421505610633
# 2119/2120[(0.9453099, 1106, 1107), (0.94533587, 578, 1099), (0.9461601, 1324, 1965), (0.94542783, 692, 1481), (0.94608986, 146, 149), (0.9462659, 110, 256), (0.9462048, 823, 1645), (0.9457379, 866, 1193), (0.94549537, 443, 1265), (0.9468926, 270, 1159)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6400, 0.87
# False Positve:958, 0.13
# True Negative:4486084, 1.00
# False Negative:958, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:11
# train_add:515
# train added: 519
# current training set length: 18877
# current save path: graphsage_model/graphsage0_11.pth
# Epoch:0,Loss:0.107251,estimated time:324.18
#  acc:0.9765852624887429
# Epoch:1000,Loss:0.012774,estimated time:232.41
#  acc:0.9896169942257774
# Epoch:2000,Loss:0.029248,estimated time:213.81
#  acc:0.9904645865338773
# Epoch:3000,Loss:0.038667,estimated time:74.444
#  acc:0.991100280764952
# 2119/2120[(0.96281195, 482, 483), (0.9628625, 242, 245), (0.9628541, 50, 863), (0.96301156, 382, 1099), (0.96289825, 14, 723), (0.9630832, 235, 691), (0.9630127, 42, 1310), (0.9641605, 77, 82), (0.9635526, 487, 2112), (0.9632813, 383, 1258)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6554, 0.89
# False Positve:804, 0.11
# True Negative:4486238, 1.00
# False Negative:804, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:12
# train_add:672
# train added: 675
# current training set length: 19552
# current save path: graphsage_model/graphsage0_12.pth
# Epoch:0,Loss:0.115466,estimated time:313.26
#  acc:0.9772401800327333
# Epoch:1000,Loss:0.026333,estimated time:215.28
#  acc:0.9895151391162029
# Epoch:2000,Loss:0.042099,estimated time:155.48
#  acc:0.9911518003273322
# Epoch:3000,Loss:0.044215,estimated time:79.460
#  acc:0.9904357610474632
# 2119/2120[(0.9346715, 868, 1358), (0.93479216, 1159, 1165), (0.934764, 315, 493), (0.93633914, 381, 1099), (0.93570983, 1275, 1543), (0.93504316, 940, 1498), (0.93497646, 377, 1159), (0.9404291, 272, 1817), (0.9409345, 1011, 1067), (0.93601286, 235, 685)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6514, 0.89
# False Positve:844, 0.11
# True Negative:4486198, 1.00
# False Negative:844, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:13
# train_add:436
# train added: 440
# current training set length: 19992
# current save path: graphsage_model/graphsage0_13.pth
# Epoch:0,Loss:0.067913,estimated time:303.50
#  acc:0.9792416966786714
# Epoch:1000,Loss:0.020515,estimated time:214.64
#  acc:0.992296918767507
# Epoch:2000,Loss:0.026370,estimated time:209.28
#  acc:0.9932472989195679
# Epoch:3000,Loss:0.003130,estimated time:81.017
#  acc:0.9946478591436575
# 2119/2120[(0.96923816, 273, 798), (0.969328, 119, 939), (0.9693505, 1120, 1121), (0.969328, 939, 1111), (0.9693699, 892, 1734), (0.9693699, 892, 1735), (0.96957153, 1282, 1555), (0.96966404, 461, 582), (0.96962667, 177, 601), (0.96973485, 555, 1643)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6792, 0.92
# False Positve:566, 0.08
# True Negative:4486476, 1.00
# False Negative:566, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:14
# train_add:479
# train added: 484
# current training set length: 20476
# current save path: graphsage_model/graphsage0_14.pth
# Epoch:0,Loss:0.061329,estimated time:295.26
#  acc:0.9856417268997851
# Epoch:1000,Loss:0.007867,estimated time:230.53
#  acc:0.9935534284039852
# Epoch:2000,Loss:0.014825,estimated time:156.17
#  acc:0.9938464543856222
# Epoch:3000,Loss:0.004451,estimated time:77.292
#  acc:0.9960441492479
# 2119/2120[(0.95407045, 1399, 1400), (0.9546135, 70, 944), (0.95423603, 433, 1570), (0.955561, 233, 1712), (0.9546304, 1254, 1919), (0.95446634, 894, 1211), (0.9543892, 14, 765), (0.95884776, 580, 1014), (0.95565796, 486, 1258), (0.9605271, 442, 1900)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6808, 0.93
# False Positve:550, 0.07
# True Negative:4486492, 1.00
# False Negative:550, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:15
# train_add:405
# train added: 406
# current training set length: 20882
# current save path: graphsage_model/graphsage0_15.pth
# Epoch:0,Loss:0.051865,estimated time:308.25
#  acc:0.9860166650703955
# Epoch:1000,Loss:0.016845,estimated time:250.16
#  acc:0.9923857868020305
# Epoch:2000,Loss:0.031285,estimated time:156.46
#  acc:0.9920026817354659
# Epoch:3000,Loss:0.017368,estimated time:80.253
#  acc:0.9934872138684034
# 2119/2120[(0.81378055, 1786, 1970), (0.8140837, 431, 751), (0.8138554, 520, 521), (0.8170409, 29, 443), (0.8165885, 463, 493), (0.81863064, 1228, 1232), (0.8176428, 864, 1093), (0.8181776, 377, 380), (0.81820065, 330, 834), (0.8180428, 787, 832)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6774, 0.92
# False Positve:584, 0.08
# True Negative:4486458, 1.00
# False Negative:584, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:16
# train_add:197
# train added: 200
# current training set length: 21082
# current save path: graphsage_model/graphsage0_16.pth
# Epoch:0,Loss:0.031543,estimated time:317.35
#  acc:0.9843468361635519
# Epoch:1000,Loss:0.018504,estimated time:249.08
#  acc:0.9916042121240869
# Epoch:2000,Loss:0.004508,estimated time:158.29
#  acc:0.9953040508490656
# Epoch:3000,Loss:0.030857,estimated time:79.241
#  acc:0.9945925434019542
# 2119/2120[(0.87131214, 931, 935), (0.87131214, 931, 945), (0.87131214, 931, 947), (0.87294585, 1106, 1358), (0.87451935, 144, 525), (0.8758632, 328, 1578), (0.8799333, 996, 1900), (0.87353015, 53, 55), (0.87837625, 687, 789), (0.87789553, 1099, 1198)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6978, 0.95
# False Positve:380, 0.05
# True Negative:4486662, 1.00
# False Negative:380, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:17
# train_add:183
# train added: 188
# current training set length: 21270
# current save path: graphsage_model/graphsage0_17.pth
# Epoch:0,Loss:0.012908,estimated time:317.68
#  acc:0.9909732016925247
# Epoch:1000,Loss:0.005088,estimated time:231.06
#  acc:0.9932299012693935
# Epoch:2000,Loss:0.011835,estimated time:156.60
#  acc:0.9964739069111425
# Epoch:3000,Loss:0.007439,estimated time:79.508
#  acc:0.9902209685002351
# 2119/2120[(0.93344253, 565, 1019), (0.93371, 492, 1124), (0.93410695, 557, 1408), (0.9366298, 506, 859), (0.9342306, 692, 798), (0.9371405, 888, 983), (0.9341392, 1310, 1687), (0.9367192, 263, 1512), (0.93852836, 652, 1093), (0.93804353, 127, 1439)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:7008, 0.95
# False Positve:350, 0.05
# True Negative:4486692, 1.00
# False Negative:350, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:18
# train_add:269
# train added: 270
# current training set length: 21540
# current save path: graphsage_model/graphsage0_18.pth
# Epoch:0,Loss:0.013500,estimated time:312.27
#  acc:0.9918291550603529
# Epoch:1000,Loss:0.025877,estimated time:231.17
#  acc:0.9953574744661096
# Epoch:2000,Loss:0.003305,estimated time:156.77
#  acc:0.9954967502321262
# Epoch:3000,Loss:0.014468,estimated time:82.305
#  acc:0.9947539461467038
# 2119/2120[(0.9454551, 450, 451), (0.9470105, 1185, 1401), (0.94605136, 347, 2117), (0.94831836, 692, 1400), (0.9485668, 498, 499), (0.9461601, 1023, 1770), (0.9460792, 378, 2112), (0.9487135, 457, 458), (0.9489047, 402, 925), (0.9487069, 329, 330)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:7056, 0.96
# False Positve:302, 0.04
# True Negative:4486740, 1.00
# False Negative:302, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:19
# train_add:225
# train added: 226
# current training set length: 21766
# current save path: graphsage_model/graphsage0_19.pth
# Epoch:0,Loss:0.074348,estimated time:304.36
#  acc:0.9915005053753561
# Epoch:1000,Loss:0.006797,estimated time:225.64
#  acc:0.9951759625103372
# Epoch:2000,Loss:0.003702,estimated time:156.94
#  acc:0.995497565009648
# Epoch:3000,Loss:0.007499,estimated time:76.122
#  acc:0.9936598364421575
# 2119/2120[(0.92255145, 499, 1802), (0.9250136, 341, 1585), (0.9225958, 248, 1632), (0.92508286, 870, 1095), (0.92508286, 870, 1097), (0.92708313, 123, 423), (0.92508286, 870, 1096), (0.92722607, 440, 663), (0.9290135, 948, 1414), (0.9258045, 823, 1370)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6972, 0.95
# False Positve:386, 0.05
# True Negative:4486656, 1.00
# False Negative:386, 0.00
# Positive:0.00
# Negative:1.00

# %%
# if you want to do reboost
graphsagemodel.load_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')

# %%
graphsagemodel.graphsage_train(boost_times=10,add_edges=1000,training_epoch=2500,
                               boost_epoch=4000,learning_rate=0.001,save_number=1)
graphsagemodel.save_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')
# Out:
# 2246140
# 3679
# -7358
# Training GraphSAGE model
# Epoch:0,Loss:0.021567,estimated time:244.03
#  acc:0.9982332155477032
# Epoch:1000,Loss:0.000063,estimated time:111.32
#  acc:0.9997281870073389
# Epoch:2000,Loss:0.000566,estimated time:40.755
#  acc:1.0
# 2119/2120[(1.0, 0, 3), (1.0, 0, 8), (1.0, 0, 6), (1.0, 0, 156), (1.0, 0, 680), (1.0, 0, 1544), (1.0, 13, 1683), (1.0, 0, 552), (1.0, 6, 490), (1.0, 8, 542)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:2530, 0.34
# False Positve:4828, 0.66
# True Negative:4482214, 1.00
# False Negative:4828, 0.00
# Positive:0.00
# Negative:1.00
# Start boosting
# boost iter:0
# train_add:965
# train added: 1000
# current training set length: 8358
# current save path: graphsage_model/graphsage1_0.pth
# Epoch:0,Loss:0.546653,estimated time:321.03
#  acc:0.9277339076334051
# Epoch:1000,Loss:0.001672,estimated time:243.18
#  acc:0.9979660205790859
# Epoch:2000,Loss:0.000241,estimated time:154.46
#  acc:0.9996410624551328
# Epoch:3000,Loss:0.000089,estimated time:87.057
#  acc:0.9997607083034219
# 2119/2120[(0.99999166, 297, 1074), (0.99999166, 413, 999), (0.99999166, 384, 1159), (0.99999166, 1315, 1316), (0.99999166, 656, 1231), (0.99999166, 767, 1477), (0.99999166, 983, 1118), (0.9999918, 299, 1308), (0.9999919, 378, 2112), (0.9999918, 692, 1074)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:3700, 0.50
# False Positve:3658, 0.50
# True Negative:4483384, 1.00
# False Negative:3658, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:1
# train_add:971
# train added: 1000
# current training set length: 9358
# current save path: graphsage_model/graphsage1_1.pth
# Epoch:0,Loss:0.618839,estimated time:333.72
#  acc:0.9422953622568925
# Epoch:1000,Loss:0.000736,estimated time:236.71
#  acc:0.9969010472323147
# Epoch:2000,Loss:0.000986,estimated time:150.94
#  acc:0.9981833725154947
# Epoch:3000,Loss:0.000733,estimated time:77.461
#  acc:1.0
# 2119/2120[(0.99988496, 436, 995), (0.99988616, 196, 222), (0.9998857, 633, 1416), (0.99988675, 376, 1990), (0.9998871, 28, 31), (0.9998864, 1647, 1853), (0.9998858, 265, 516), (0.99988735, 338, 1973), (0.9998871, 133, 217), (0.9998882, 84, 85)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:4256, 0.58
# False Positve:3102, 0.42
# True Negative:4483940, 1.00
# False Negative:3102, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:2
# train_add:947
# train added: 1000
# current training set length: 10358
# current save path: graphsage_model/graphsage1_2.pth
# Epoch:0,Loss:0.383977,estimated time:313.89
#  acc:0.9456458775825449
# Epoch:1000,Loss:0.001792,estimated time:240.59
#  acc:0.9960417068932226
# Epoch:2000,Loss:0.002537,estimated time:157.20
#  acc:0.998648387719637
# Epoch:3000,Loss:0.002428,estimated time:80.744
#  acc:0.9964278818304692
# 2119/2120[(0.99977154, 490, 495), (0.9997725, 1093, 1260), (0.99977213, 685, 859), (0.9997727, 215, 318), (0.999775, 607, 1972), (0.9997725, 338, 987), (0.9997739, 231, 859), (0.99977654, 507, 671), (0.9997732, 202, 1873), (0.999775, 607, 1973)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:5164, 0.70
# False Positve:2194, 0.30
# True Negative:4484848, 1.00
# False Negative:2194, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:3
# train_add:951
# train added: 1000
# current training set length: 11358
# current save path: graphsage_model/graphsage1_3.pth
# Epoch:0,Loss:0.209634,estimated time:325.48
#  acc:0.9556259904912837
# Epoch:1000,Loss:0.011695,estimated time:230.80
#  acc:0.9969184715618947
# Epoch:2000,Loss:0.024444,estimated time:147.78
#  acc:0.9955978165169924
# Epoch:3000,Loss:0.002724,estimated time:76.024
#  acc:0.9976228209191759
# 2119/2120[(0.9993961, 1656, 1657), (0.9993962, 209, 892), (0.99939847, 354, 452), (0.9994043, 1537, 1543), (0.99939764, 30, 920), (0.9994017, 384, 864), (0.9994091, 338, 339), (0.999405, 809, 1088), (0.99940634, 54, 1011), (0.9993992, 759, 762)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:5742, 0.78
# False Positve:1616, 0.22
# True Negative:4485426, 1.00
# False Negative:1616, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:4
# train_add:988
# train added: 1000
# current training set length: 12358
# current save path: graphsage_model/graphsage1_4.pth
# Epoch:0,Loss:0.300430,estimated time:330.07
#  acc:0.9623725521929115
# Epoch:1000,Loss:0.003319,estimated time:215.80
#  acc:0.9957921993850137
# Epoch:2000,Loss:0.022523,estimated time:150.56
#  acc:0.9962777148405891
# Epoch:3000,Loss:0.002116,estimated time:78.789
#  acc:0.9974915034795274
# 2119/2120[(0.9969897, 1515, 1957), (0.99699616, 240, 247), (0.9970084, 8, 880), (0.9970005, 1133, 1135), (0.99699855, 64, 2042), (0.997013, 759, 761), (0.9970594, 95, 100), (0.9970091, 762, 2112), (0.99702877, 1311, 2052), (0.9970214, 535, 1856)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6104, 0.83
# False Positve:1254, 0.17
# True Negative:4485788, 1.00
# False Negative:1254, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:5
# train_add:997
# train added: 1000
# current training set length: 13358
# current save path: graphsage_model/graphsage1_5.pth
# Epoch:0,Loss:0.258895,estimated time:324.78
#  acc:0.9653391226231471
# Epoch:1000,Loss:0.010378,estimated time:212.69
#  acc:0.9950591405899086
# Epoch:2000,Loss:0.067469,estimated time:154.02
#  acc:0.9939362179967061
# Epoch:3000,Loss:0.018209,estimated time:73.095
#  acc:0.9938613564904926
# 2119/2120[(0.99557364, 167, 1800), (0.99558485, 441, 583), (0.99560225, 224, 586), (0.99561995, 589, 989), (0.99559647, 79, 2059), (0.9956071, 1217, 1219), (0.9956969, 745, 1823), (0.9956317, 798, 799), (0.99570245, 1755, 2047), (0.9956482, 281, 931)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6248, 0.85
# False Positve:1110, 0.15
# True Negative:4485932, 1.00
# False Negative:1110, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:6
# train_add:990
# train added: 1000
# current training set length: 14358
# current save path: graphsage_model/graphsage1_6.pth
# Epoch:0,Loss:0.301675,estimated time:339.56
#  acc:0.9623903050564145
# Epoch:1000,Loss:0.010793,estimated time:244.45
#  acc:0.9913636996796211
# Epoch:2000,Loss:0.007535,estimated time:154.56
#  acc:0.9963783256720992
# Epoch:3000,Loss:0.012252,estimated time:75.904
#  acc:0.9967962111714723
# 2119/2120[(0.9621762, 182, 236), (0.9623697, 145, 645), (0.96219194, 1072, 1453), (0.9625869, 1493, 1960), (0.9635291, 233, 433), (0.9625098, 623, 624), (0.96283275, 727, 1498), (0.9629029, 1070, 1185), (0.96457046, 351, 352), (0.96353513, 384, 2112)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6562, 0.89
# False Positve:796, 0.11
# True Negative:4486246, 1.00
# False Negative:796, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:7
# train_add:454
# train added: 459
# current training set length: 14817
# current save path: graphsage_model/graphsage1_7.pth
# Epoch:0,Loss:0.141524,estimated time:300.99
#  acc:0.9731389620031046
# Epoch:1000,Loss:0.009786,estimated time:229.73
#  acc:0.9948707565634068
# Epoch:2000,Loss:0.011641,estimated time:162.16
#  acc:0.9939258959303503
# Epoch:3000,Loss:0.003634,estimated time:78.951
#  acc:0.9952756968347168
# 2119/2120[(0.96548724, 199, 222), (0.96562606, 942, 1499), (0.9657328, 994, 1656), (0.96660346, 257, 288), (0.9662208, 1188, 1257), (0.96748513, 627, 1263), (0.9661273, 172, 173), (0.96665347, 1188, 2078), (0.96797514, 183, 1539), (0.9681852, 790, 791)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6822, 0.93
# False Positve:536, 0.07
# True Negative:4486506, 1.00
# False Negative:536, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:8
# train_add:381
# train added: 385
# current training set length: 15202
# current save path: graphsage_model/graphsage1_8.pth
# Epoch:0,Loss:0.102786,estimated time:330.07
#  acc:0.974871727404289
# Epoch:1000,Loss:0.049568,estimated time:232.32
#  acc:0.9962504933561374
# Epoch:2000,Loss:0.013008,estimated time:167.56
#  acc:0.9954611235363768
# Epoch:3000,Loss:0.006211,estimated time:81.807
#  acc:0.9951980002631233
# 2119/2120[(0.98644173, 621, 1595), (0.98644316, 218, 1318), (0.98650986, 985, 1278), (0.9865437, 462, 464), (0.98661995, 333, 334), (0.98670954, 692, 799), (0.98682624, 827, 1243), (0.9866291, 894, 1622), (0.98665583, 810, 1755), (0.98683727, 1099, 1105)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6846, 0.93
# False Positve:512, 0.07
# True Negative:4486530, 1.00
# False Negative:512, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:9
# train_add:534
# train added: 538
# current training set length: 15740
# current save path: graphsage_model/graphsage1_9.pth
# Epoch:0,Loss:0.063216,estimated time:300.77
#  acc:0.9845616264294791
# Epoch:1000,Loss:0.005919,estimated time:274.74
#  acc:0.9970775095298602
# Epoch:2000,Loss:0.034435,estimated time:165.83
#  acc:0.996569250317662
# Epoch:3000,Loss:0.005837,estimated time:82.310
#  acc:0.9966963151207116
# 2119/2120[(0.8807663, 1289, 1757), (0.8809021, 184, 1100), (0.88098186, 487, 767), (0.88292587, 1352, 1354), (0.88353395, 743, 1345), (0.88122797, 598, 599), (0.8824132, 372, 694), (0.8890421, 719, 2016), (0.88511765, 406, 1482), (0.88968426, 125, 127)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6942, 0.94
# False Positve:416, 0.06
# True Negative:4486626, 1.00
# False Negative:416, 0.00
# Positive:0.00
# Negative:1.00

# %% [markdown]
# # *1.2 Load pretrained model*

# %%
graphsagemodel.load_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')

# %%
embedding_matrix_numpy=graphsagemodel.embedding_matrix_numpy
link_prediction_model=graphsagemodel.graphsage_link_prediction_from_embedding_one_to_other
predict_adj=graph_utils.evaluate_overlap_torch(_N=_N,
                                                    _num_of_edges=_num_of_edges,
                                                    adj_origin=adj_origin,
                                                    embedding_matrix_numpy=embedding_matrix_numpy,
                                                    link_prediction_from_embedding_one_to_other=link_prediction_model)
# Out:
# 2119/2120[(0.8820486, 197, 767), (0.8822426, 401, 1177), (0.88220215, 1161, 1210), (0.8867349, 257, 415), (0.8824132, 372, 694), (0.88623327, 469, 476), (0.89217174, 862, 1159), (0.88820344, 681, 682), (0.8890421, 719, 2016), (0.8982855, 1159, 1195)]
# 1.0
# (2120, 2120)
# 7358
# 7358
# True Positve:6960, 0.95
# False Positve:398, 0.05
# True Negative:4486644, 1.00
# False Negative:398, 0.00
# Positive:0.00
# Negative:1.00

# %%
metric_embedding=graph_utils.compute_graph_statistics(predict_adj)
metric_origin=graph_utils.compute_graph_statistics(adj_origin)
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# /opt/anaconda3/lib/python3.7/site-packages/powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))

# %%
for x in metric_origin:
    print('%-25s origin:%17.8f, link_pred:%17.8f'%(x,metric_origin[x],metric_embedding[x]))
# Out:
# d_max                     origin:      99.00000000, link_pred:      75.00000000
# d_min                     origin:       1.00000000, link_pred:       0.00000000
# d                         origin:       3.47075472, link_pred:       3.47075472
# LCC                       origin:    2120.00000000, link_pred:    2096.00000000
# wedge_count               origin:   25974.00000000, link_pred:   22890.00000000
# claw_count                origin:  250382.00000000, link_pred:  145966.00000000
# triangle_count            origin:    1084.00000000, link_pred:     868.00000000
# square_count              origin:     249.00000000, link_pred:     120.00000000
# power_law_exp             origin:       2.07078423, link_pred:       2.04773937
# gini                      origin:       0.42760979, link_pred:       0.42354336
# rel_edge_distr_entropy    origin:       0.95385514, link_pred:       0.95643662
# assortativity             origin:       0.00750617, link_pred:      -0.01848155
# clustering_coefficient    origin:       0.01298815, link_pred:       0.01783977
# n_components              origin:       1.00000000, link_pred:      21.00000000
# cpl                       origin:       9.32971453, link_pred:       8.34957439
