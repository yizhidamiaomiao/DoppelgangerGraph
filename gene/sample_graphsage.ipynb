# %%
import networkx as nx
import scipy.sparse as sp
import numpy as np
import graph_utils as utils
import torch
import os
from collections import defaultdict
import numpy as np
import time
import json

# %%
seed=114514
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.seed_all()

# %% [markdown]
# # **Read data**

# %%
loader = np.load('gene_with_label.npz')
train_ones = loader['edges']
print(len(train_ones))
print(train_ones[:5])
# Out:
# 2872
# [[  0  60]
#  [  0 622]
#  [  1 345]
#  [  2  39]
#  [  2  56]]

# %%
adj_sparse = np.zeros((np.max(train_ones)+1,np.max(train_ones)+1))
for e in train_ones:
    adj_sparse[e[0],e[1]]=1
    adj_sparse[e[1],e[0]]=1
    
adj_sparse = sp.coo_matrix(adj_sparse).tocsr()

lcc = utils.largest_connected_components(adj_sparse)
adj_sparse= adj_sparse[lcc,:][:,lcc]
_N = adj_sparse.shape[0]
print('n',_N)
_Edges=[]
for x in np.column_stack(adj_sparse.nonzero()):
    if not x[0]==x[1]:
        _Edges.append((x[0],x[1]))
_num_of_edges=int(len(_Edges)/2)
print('m',_num_of_edges)

dic=defaultdict(set)
for x in _Edges:
    a1=x[0]
    a2=x[1]
    dic[a1].add(a2)
    dic[a2].add(a1)
    

adj_origin=np.zeros((_N,_N)).astype(int)
for (i,j) in _Edges:
    adj_origin[i][j]=1
    adj_origin[j][i]=1
assert(np.sum(adj_origin==adj_origin.T)==_N*_N)
assert(np.sum(adj_origin)==_num_of_edges*2)
# Out:
# Selecting 1 largest connected components
# n 814
# m 1436

# %% [markdown]
# # **1.Get link prediction model and embedding**

# %%
embedding_dim=128

graphsagemodel=utils.GraphSAGE(_N=_N,_M=_num_of_edges,adj_origin=adj_origin,
                                         adj_dic=dic,embedding_dim=embedding_dim)

# %% [markdown]
# # *1.1 Training step*

# %%
graphsagemodel.graphsage_train(boost_times=20,add_edges=1000,training_epoch=2500,
                               boost_epoch=4000,learning_rate=0.001,save_number=0)
graphsagemodel.save_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')
# Out:
# 330891
# 1436
# -2872
# Training GraphSAGE model
# Epoch:0,Loss:0.693375,estimated time:90.94
#  acc:0.5
# Epoch:1000,Loss:0.001911,estimated time:46.95
#  acc:0.9986072423398329
# Epoch:2000,Loss:0.003433,estimated time:15.61
#  acc:0.9996518105849582
# 813/814[(1.0, 0, 85), (1.0, 0, 143), (1.0, 0, 101), (1.0, 0, 154), (1.0, 0, 167), (1.0, 0, 193), (1.0, 1, 116), (1.0, 0, 260), (1.0, 0, 304), (1.0, 0, 170)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:290, 0.10
# False Positve:2582, 0.90
# True Negative:657142, 1.00
# False Negative:2582, 0.00
# Positive:0.00
# Negative:1.00
# Start boosting
# boost iter:0
# train_add:0
# train added: 1000
# current training set length: 3872
# current save path: graphsage_model/graphsage0_0.pth
# Epoch:0,Loss:1.756825,estimated time:170.28
#  acc:0.8075929752066116
# Epoch:1000,Loss:0.067748,estimated time:100.98
#  acc:0.987345041322314
# Epoch:2000,Loss:0.010994,estimated time:59.956
#  acc:0.9940599173553719
# Epoch:3000,Loss:0.013563,estimated time:32.44
#  acc:0.9963842975206612
# 813/814[(0.9999999, 426, 482), (0.9999999, 426, 571), (0.9999999, 427, 520), (0.9999999, 427, 708), (0.9999999, 426, 689), (0.9999999, 427, 672), (0.9999999, 448, 457), (0.9999999, 448, 453), (0.9999999, 431, 434), (0.9999999, 427, 629)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:630, 0.22
# False Positve:2242, 0.78
# True Negative:657482, 1.00
# False Negative:2242, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:1
# train_add:562
# train added: 1000
# current training set length: 4872
# current save path: graphsage_model/graphsage0_1.pth
# Epoch:0,Loss:1.265778,estimated time:152.20
#  acc:0.8497536945812808
# Epoch:1000,Loss:0.067457,estimated time:99.51
#  acc:0.9821428571428571
# Epoch:2000,Loss:0.054196,estimated time:68.965
#  acc:0.9866584564860427
# Epoch:3000,Loss:0.026665,estimated time:33.03
#  acc:0.9889162561576355
# 813/814[(0.9999815, 14, 478), (0.9999815, 143, 813), (0.9999815, 422, 638), (0.9999815, 146, 370), (0.99998176, 256, 483), (0.9999825, 267, 785), (0.99998176, 536, 546), (0.9999826, 303, 649), (0.9999815, 423, 812), (0.9999821, 420, 634)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:900, 0.31
# False Positve:1972, 0.69
# True Negative:657752, 1.00
# False Negative:1972, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:2
# train_add:990
# train added: 1000
# current training set length: 5872
# current save path: graphsage_model/graphsage0_2.pth
# Epoch:0,Loss:1.189387,estimated time:152.32
#  acc:0.8732970027247956
# Epoch:1000,Loss:0.078095,estimated time:91.58
#  acc:0.9758174386920981
# Epoch:2000,Loss:0.050912,estimated time:62.469
#  acc:0.982799727520436
# Epoch:3000,Loss:0.058629,estimated time:29.94
#  acc:0.974625340599455
# 813/814[(0.9986388, 404, 645), (0.9986518, 4, 382), (0.99864274, 136, 260), (0.9987017, 507, 600), (0.9986518, 294, 382), (0.9986771, 314, 445), (0.99866164, 259, 492), (0.9987226, 512, 807), (0.9987081, 305, 319), (0.99866354, 73, 92)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:1316, 0.46
# False Positve:1556, 0.54
# True Negative:658168, 1.00
# False Negative:1556, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:3
# train_add:993
# train added: 1000
# current training set length: 6872
# current save path: graphsage_model/graphsage0_3.pth
# Epoch:0,Loss:0.597347,estimated time:133.52
#  acc:0.8683061699650757
# Epoch:1000,Loss:0.080522,estimated time:95.27
#  acc:0.9668218859138533
# Epoch:2000,Loss:0.073929,estimated time:70.370
#  acc:0.9714784633294529
# Epoch:3000,Loss:0.057872,estimated time:32.00
#  acc:0.9780267753201397
# 813/814[(0.9477714, 296, 313), (0.94795185, 359, 787), (0.9484051, 112, 384), (0.9481316, 141, 305), (0.9481438, 328, 417), (0.9488958, 621, 686), (0.9491918, 253, 264), (0.9483605, 141, 150), (0.94819206, 236, 813), (0.94853187, 481, 499)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:1808, 0.63
# False Positve:1064, 0.37
# True Negative:658660, 1.00
# False Negative:1064, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:4
# train_add:993
# train added: 1000
# current training set length: 7872
# current save path: graphsage_model/graphsage0_4.pth
# Epoch:0,Loss:0.945743,estimated time:147.48
#  acc:0.8702997967479674
# Epoch:1000,Loss:0.111892,estimated time:122.83
#  acc:0.9542682926829268
# Epoch:2000,Loss:0.096552,estimated time:62.702
#  acc:0.9594766260162602
# Epoch:3000,Loss:0.113874,estimated time:33.92
#  acc:0.9660823170731707
# 813/814[(0.506336, 517, 660), (0.50904536, 166, 358), (0.5110064, 183, 755), (0.51016086, 344, 734), (0.5095686, 248, 628), (0.514464, 183, 793), (0.51301575, 97, 276), (0.5115853, 331, 350), (0.51048636, 81, 82), (0.509705, 182, 239)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2276, 0.79
# False Positve:596, 0.21
# True Negative:659128, 1.00
# False Negative:596, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:5
# train_add:308
# train added: 308
# current training set length: 8180
# current save path: graphsage_model/graphsage0_5.pth
# Epoch:0,Loss:0.347174,estimated time:136.62
#  acc:0.9133251833740831
# Epoch:1000,Loss:0.087714,estimated time:98.69
#  acc:0.9621026894865525
# Epoch:2000,Loss:0.084910,estimated time:63.297
#  acc:0.9671149144254279
# Epoch:3000,Loss:0.090789,estimated time:32.55
#  acc:0.9734718826405868
# 813/814[(0.8293505, 192, 371), (0.8304883, 337, 344), (0.8316011, 303, 350), (0.8319491, 110, 301), (0.8307166, 244, 248), (0.8331176, 541, 669), (0.8317284, 46, 367), (0.835526, 48, 359), (0.83465207, 16, 106), (0.8319834, 84, 774)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2464, 0.86
# False Positve:408, 0.14
# True Negative:659316, 1.00
# False Negative:408, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:6
# train_add:468
# train added: 470
# current training set length: 8650
# current save path: graphsage_model/graphsage0_6.pth
# Epoch:0,Loss:0.139781,estimated time:133.99
#  acc:0.9204624277456648
# Epoch:1000,Loss:0.061995,estimated time:94.03
#  acc:0.9778034682080925
# Epoch:2000,Loss:0.056573,estimated time:59.832
#  acc:0.9796531791907515
# Epoch:3000,Loss:0.086106,estimated time:33.20
#  acc:0.979421965317919
# 813/814[(0.76379865, 164, 374), (0.7640844, 44, 71), (0.7641152, 330, 777), (0.76562935, 523, 716), (0.7664508, 130, 203), (0.7660824, 114, 152), (0.7698249, 66, 123), (0.772149, 536, 735), (0.7702601, 427, 449), (0.77892554, 280, 439)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2602, 0.91
# False Positve:270, 0.09
# True Negative:659454, 1.00
# False Negative:270, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:7
# train_add:252
# train added: 252
# current training set length: 8902
# current save path: graphsage_model/graphsage0_7.pth
# Epoch:0,Loss:0.131176,estimated time:143.28
#  acc:0.9377667939788812
# Epoch:1000,Loss:0.047135,estimated time:99.08
#  acc:0.9806784992136599
# Epoch:2000,Loss:0.059939,estimated time:69.644
#  acc:0.9829251853516063
# Epoch:3000,Loss:0.034909,estimated time:29.31
#  acc:0.9876432262412941
# 813/814[(0.56545997, 130, 616), (0.5697766, 75, 127), (0.56654733, 485, 680), (0.5823253, 409, 536), (0.5697766, 127, 561), (0.5697766, 127, 275), (0.57227165, 362, 430), (0.5988683, 480, 694), (0.59192187, 15, 225), (0.5779434, 114, 239)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2626, 0.91
# False Positve:246, 0.09
# True Negative:659478, 1.00
# False Negative:246, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:8
# train_add:107
# train added: 107
# current training set length: 9009
# current save path: graphsage_model/graphsage0_8.pth
# Epoch:0,Loss:0.057358,estimated time:141.54
#  acc:0.9683649683649683
# Epoch:1000,Loss:0.010081,estimated time:100.27
#  acc:0.9851259851259851
# Epoch:2000,Loss:0.051171,estimated time:64.833
#  acc:0.9851259851259851
# Epoch:3000,Loss:0.045245,estimated time:31.95
#  acc:0.9821289821289821
# 813/814[(0.6388996, 43, 72), (0.64350826, 201, 239), (0.6448594, 425, 702), (0.6462791, 164, 374), (0.64413023, 284, 303), (0.6448648, 335, 420), (0.67904896, 257, 785), (0.6514605, 130, 664), (0.6506041, 152, 358), (0.6467729, 512, 645)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2708, 0.94
# False Positve:164, 0.06
# True Negative:659560, 1.00
# False Negative:164, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:9
# train_add:127
# train added: 127
# current training set length: 9136
# current save path: graphsage_model/graphsage0_9.pth
# Epoch:0,Loss:0.027874,estimated time:134.47
#  acc:0.9757005253940455
# Epoch:1000,Loss:0.064319,estimated time:94.51
#  acc:0.9877408056042032
# Epoch:2000,Loss:0.019431,estimated time:68.916
#  acc:0.9859894921190894
# Epoch:3000,Loss:0.061195,estimated time:34.09
#  acc:0.9874124343257443
# 813/814[(0.58680224, 83, 628), (0.5885257, 423, 573), (0.59598744, 171, 622), (0.5901863, 150, 182), (0.5936446, 607, 613), (0.5981349, 130, 567), (0.6037857, 540, 575), (0.6202, 417, 791), (0.5971, 536, 577), (0.6029919, 54, 196)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2694, 0.94
# False Positve:178, 0.06
# True Negative:659546, 1.00
# False Negative:178, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:10
# train_add:83
# train added: 83
# current training set length: 9219
# current save path: graphsage_model/graphsage0_10.pth
# Epoch:0,Loss:0.035940,estimated time:148.73
#  acc:0.9616010413276929
# Epoch:1000,Loss:0.035741,estimated time:94.84
#  acc:0.9856817442238854
# Epoch:2000,Loss:0.041076,estimated time:64.589
#  acc:0.9877427052825686
# Epoch:3000,Loss:0.041118,estimated time:33.05
#  acc:0.9893697798025817
# 813/814[(0.57738805, 528, 539), (0.5774664, 517, 711), (0.5883585, 281, 319), (0.5886392, 448, 527), (0.5836493, 631, 724), (0.6141438, 147, 420), (0.59046054, 91, 305), (0.6154471, 239, 281), (0.59446883, 498, 520), (0.5937511, 440, 456)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2730, 0.95
# False Positve:142, 0.05
# True Negative:659582, 1.00
# False Negative:142, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:11
# train_add:93
# train added: 93
# current training set length: 9312
# current save path: graphsage_model/graphsage0_11.pth
# Epoch:0,Loss:0.019427,estimated time:145.27
#  acc:0.9792740549828178
# Epoch:1000,Loss:0.056714,estimated time:125.76
#  acc:0.9887242268041238
# Epoch:2000,Loss:0.026775,estimated time:68.961
#  acc:0.9917310996563574
# Epoch:3000,Loss:0.018265,estimated time:34.19
#  acc:0.9890463917525774
# 813/814[(0.60670036, 551, 702), (0.6074654, 286, 755), (0.6140429, 182, 261), (0.61982507, 170, 192), (0.609997, 659, 703), (0.61531997, 15, 266), (0.6272885, 435, 732), (0.6256834, 165, 602), (0.6256834, 92, 165), (0.6367617, 8, 182)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2716, 0.95
# False Positve:156, 0.05
# True Negative:659568, 1.00
# False Negative:156, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:12
# train_add:107
# train added: 108
# current training set length: 9420
# current save path: graphsage_model/graphsage0_12.pth
# Epoch:0,Loss:0.070741,estimated time:153.53
#  acc:0.9794055201698514
# Epoch:1000,Loss:0.027144,estimated time:93.04
#  acc:0.9917197452229299
# Epoch:2000,Loss:0.025020,estimated time:69.769
#  acc:0.9876857749469214
# Epoch:3000,Loss:0.011145,estimated time:33.09
#  acc:0.990552016985138
# 813/814[(0.54841286, 99, 138), (0.55053025, 83, 793), (0.55006516, 139, 319), (0.5567617, 207, 473), (0.57618517, 156, 350), (0.5520653, 114, 239), (0.62407017, 528, 551), (0.5826798, 4, 294), (0.62320906, 410, 596), (0.5939915, 127, 747)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2768, 0.96
# False Positve:104, 0.04
# True Negative:659620, 1.00
# False Negative:104, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:13
# train_add:75
# train added: 75
# current training set length: 9495
# current save path: graphsage_model/graphsage0_13.pth
# Epoch:0,Loss:0.051229,estimated time:138.86
#  acc:0.9878883622959452
# Epoch:1000,Loss:0.031207,estimated time:106.38
#  acc:0.989468141126909
# Epoch:2000,Loss:0.020052,estimated time:66.739
#  acc:0.9818852027382833
# Epoch:3000,Loss:0.042563,estimated time:33.61
#  acc:0.9912585571353344
# 813/814[(0.5101936, 448, 729), (0.51057595, 646, 769), (0.5215361, 485, 498), (0.51931936, 55, 114), (0.5151115, 131, 232), (0.55108374, 169, 807), (0.533586, 405, 673), (0.5470446, 152, 259), (0.5534127, 503, 704), (0.54303885, 408, 485)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2742, 0.95
# False Positve:130, 0.05
# True Negative:659594, 1.00
# False Negative:130, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:14
# train_add:63
# train added: 64
# current training set length: 9559
# current save path: graphsage_model/graphsage0_14.pth
# Epoch:0,Loss:0.023094,estimated time:146.40
#  acc:0.983157234020295
# Epoch:1000,Loss:0.031638,estimated time:101.86
#  acc:0.991003243017052
# Epoch:2000,Loss:0.022948,estimated time:69.705
#  acc:0.9896432681242808
# Epoch:3000,Loss:0.017600,estimated time:33.89
#  acc:0.9914216968302124
# 813/814[(0.69214195, 182, 239), (0.6951389, 92, 160), (0.69264233, 114, 239), (0.6951389, 160, 602), (0.7149278, 541, 760), (0.69315606, 498, 520), (0.6951389, 160, 391), (0.72236836, 451, 534), (0.6971734, 150, 297), (0.7242386, 139, 297)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2728, 0.95
# False Positve:144, 0.05
# True Negative:659580, 1.00
# False Negative:144, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:15
# train_add:131
# train added: 131
# current training set length: 9690
# current save path: graphsage_model/graphsage0_15.pth
# Epoch:0,Loss:0.031386,estimated time:143.39
#  acc:0.9805985552115583
# Epoch:1000,Loss:0.031361,estimated time:97.91
#  acc:0.9919504643962849
# Epoch:2000,Loss:0.050363,estimated time:63.397
#  acc:0.9927760577915377
# Epoch:3000,Loss:0.017685,estimated time:33.82
#  acc:0.9925696594427245
# 813/814[(0.80202264, 2, 338), (0.8041302, 110, 266), (0.8273249, 498, 520), (0.8144611, 525, 527), (0.8170001, 486, 662), (0.8331126, 239, 297), (0.83895206, 186, 595), (0.8414644, 434, 737), (0.8170001, 451, 662), (0.81700397, 231, 363)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2744, 0.96
# False Positve:128, 0.04
# True Negative:659596, 1.00
# False Negative:128, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:16
# train_add:108
# train added: 109
# current training set length: 9799
# current save path: graphsage_model/graphsage0_16.pth
# Epoch:0,Loss:0.038364,estimated time:144.75
#  acc:0.9873456475150526
# Epoch:1000,Loss:0.019863,estimated time:111.67
#  acc:0.9898969282579855
# Epoch:2000,Loss:0.011262,estimated time:65.598
#  acc:0.9954076946627207
# Epoch:3000,Loss:0.021448,estimated time:35.72
#  acc:0.993570772527809
# 813/814[(0.66042703, 527, 668), (0.6621603, 721, 794), (0.6641247, 70, 276), (0.67262894, 201, 671), (0.66311586, 142, 734), (0.7166819, 446, 647), (0.67620367, 498, 520), (0.67509043, 460, 528), (0.67550904, 43, 71), (0.66705877, 142, 232)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2768, 0.96
# False Positve:104, 0.04
# True Negative:659620, 1.00
# False Negative:104, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:17
# train_add:65
# train added: 66
# current training set length: 9865
# current save path: graphsage_model/graphsage0_17.pth
# Epoch:0,Loss:0.018801,estimated time:141.20
#  acc:0.9811454637607704
# Epoch:1000,Loss:0.008834,estimated time:97.55
#  acc:0.9929042067916878
# Epoch:2000,Loss:0.012047,estimated time:77.876
#  acc:0.993613786112519
# Epoch:3000,Loss:0.018790,estimated time:33.86
#  acc:0.9930055752660922
# 813/814[(0.53833926, 486, 534), (0.54575384, 248, 366), (0.5640334, 416, 807), (0.5543835, 114, 152), (0.55253965, 127, 805), (0.5678053, 150, 323), (0.58874553, 120, 166), (0.5773283, 5, 74), (0.5568512, 329, 439), (0.5642759, 528, 716)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2760, 0.96
# False Positve:112, 0.04
# True Negative:659612, 1.00
# False Negative:112, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:18
# train_add:47
# train added: 47
# current training set length: 9912
# current save path: graphsage_model/graphsage0_18.pth
# Epoch:0,Loss:0.019241,estimated time:157.70
#  acc:0.9806295399515739
# Epoch:1000,Loss:0.049781,estimated time:96.58
#  acc:0.9926351896690879
# Epoch:2000,Loss:0.010882,estimated time:69.511
#  acc:0.9907183212267958
# Epoch:3000,Loss:0.028694,estimated time:32.78
#  acc:0.9928369652945924
# 813/814[(0.5158655, 668, 801), (0.5238578, 164, 374), (0.51930505, 152, 355), (0.53579193, 89, 113), (0.5318173, 140, 300), (0.5543065, 562, 663), (0.5210606, 166, 807), (0.54944944, 141, 807), (0.53630376, 89, 249), (0.5515559, 551, 702)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2794, 0.97
# False Positve:78, 0.03
# True Negative:659646, 1.00
# False Negative:78, 0.00
# Positive:0.00
# Negative:1.00
# boost iter:19
# train_add:39
# train added: 39
# current training set length: 9951
# current save path: graphsage_model/graphsage0_19.pth
# Epoch:0,Loss:0.026770,estimated time:146.32
#  acc:0.9907546980202995
# Epoch:1000,Loss:0.014502,estimated time:112.94
#  acc:0.9942719324690986
# Epoch:2000,Loss:0.019136,estimated time:69.617
#  acc:0.9924630690382876
# Epoch:3000,Loss:0.011080,estimated time:33.46
#  acc:0.9956788262486183
# 813/814[(0.61579, 84, 302), (0.6310142, 386, 802), (0.63691473, 451, 788), (0.6815589, 109, 425), (0.6315968, 20, 635), (0.6658866, 138, 296), (0.6815589, 425, 515), (0.69950783, 51, 685), (0.68225193, 179, 673), (0.63691473, 486, 788)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2762, 0.96
# False Positve:110, 0.04
# True Negative:659614, 1.00
# False Negative:110, 0.00
# Positive:0.00
# Negative:1.00

# %%
# if you want to do reboost
graphsagemodel.load_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')

# %%
graphsagemodel.graphsage_train(boost_times=10,add_edges=1000,training_epoch=2500,
                               boost_epoch=4000,learning_rate=0.001,save_number=1)
graphsagemodel.save_model(path='graphsage_model/graph_graphsageAA.pth',embedding_path='graphsage_model/embeddingsAA.npy')

# %% [markdown]
# # *1.2 Load pretrained model*

# %%
graphsagemodel.load_model(path='graphsage_model/graph_graphsage.pth',embedding_path='graphsage_model/embeddings.npy')

# %%
embedding_matrix_numpy=graphsagemodel.embedding_matrix_numpy
link_prediction_model=graphsagemodel.graphsage_link_prediction_from_embedding_one_to_other
predict_adj=utils.evaluate_overlap_torch(_N=_N,
                                                    _num_of_edges=_num_of_edges,
                                                    adj_origin=adj_origin,
                                                    embedding_matrix_numpy=embedding_matrix_numpy,
                                                    link_prediction_from_embedding_one_to_other=link_prediction_model)
# Out:
# 813/814[(0.6239317, 114, 297), (0.6242199, 511, 797), (0.63082474, 120, 297), (0.6310142, 386, 802), (0.62630093, 477, 731), (0.6699211, 159, 305), (0.6359365, 408, 668), (0.6691241, 120, 166), (0.6322952, 120, 150), (0.63624847, 183, 769)]
# 1.0
# (814, 814)
# 2872
# 2872
# True Positve:2778, 0.97
# False Positve:94, 0.03
# True Negative:659630, 1.00
# False Negative:94, 0.00
# Positive:0.00
# Negative:1.00

# %%
metric_embedding=utils.compute_graph_statistics(predict_adj)
metric_origin=utils.compute_graph_statistics(adj_origin)
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# /opt/anaconda3/lib/python3.7/site-packages/powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))

# %%
for x in metric_origin:
    print('%-25s origin:%17.8f, link_pred:%17.8f'%(x,metric_origin[x],metric_embedding[x]))
# Out:
# d_max                     origin:      29.00000000, link_pred:      29.00000000
# d_min                     origin:       1.00000000, link_pred:       0.00000000
# d                         origin:       3.52825553, link_pred:       3.52825553
# LCC                       origin:     814.00000000, link_pred:     806.00000000
# wedge_count               origin:    7786.00000000, link_pred:    7526.00000000
# claw_count                origin:   23322.00000000, link_pred:   21661.00000000
# triangle_count            origin:     809.00000000, link_pred:     681.00000000
# square_count              origin:     968.00000000, link_pred:     537.00000000
# power_law_exp             origin:       2.05426571, link_pred:       2.03385673
# gini                      origin:       0.42572701, link_pred:       0.41770239
# rel_edge_distr_entropy    origin:       0.95303593, link_pred:       0.95496390
# assortativity             origin:       0.13561540, link_pred:       0.03567548
# clustering_coefficient    origin:       0.10406483, link_pred:       0.09431698
# n_components              origin:       1.00000000, link_pred:       6.00000000
# cpl                       origin:       7.00830485, link_pred:       6.79509033
